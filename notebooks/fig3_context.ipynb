# %% [markdown]
# # Fig 3 draft: behavioral context (Passive / Repeat / Decision)
#
# Linear: **SHI-57**. Paper title: *Insula response depends differently on behavioral context*.
#
# Old claim (AIC / PIC): **AIC** fired more in Decision than Repeat, and was silent in Passive.
# This notebook redraws that contrast on canonical NMF clusters (`sustain` / `motor` / `sensory`).
#
# Panels are separate SVGs (assemble in Adobe):
#
# 1. **Waveforms** — cluster rows × phase columns; hue = condition. Same electrodes in every condition (subject sig-union ∩ NMF assignments).
# 2. **Spatial** — LexicalDelay `DecisionVsRepeatMean`, Decision larger, phase union. Fig 2 insula render; fixed point size.
#
# First-pass tasks (the three-condition story):
#
# | Condition | Where it lives |
# |-----------|----------------|
# | Repeat, Decision | LexicalDelay |
# | Passive (+ Repeat, Decision) | LexicalNoDelay |
#
# A later **Pooled conditions** block concatenates Repeat / Decision / Passive
# across LexicalDelay, LexicalNoDelay, PictureNaming (sound), and PhonemeSequence.
#
# Run the load cells on a compute node, not the login node.
#
# Style: [`docs/PLOTTING_STYLE.md`](../docs/PLOTTING_STYLE.md). SVG only.

# %%
# %matplotlib inline

import sys
from collections import defaultdict
from pathlib import Path

import matplotlib.pyplot as plt
import mne
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import SVG, display
from mne_bids import BIDSPath
from tqdm.auto import tqdm

ROOT = Path("..").resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.connectivity.pairwise.config import DEFAULT_DATASETS
from src.nmf.waveform_analysis import CLUSTER_LABELS, FUNCTION_COLORS
from src.paths import img_dir, nmf_assignments_path, save_svg

# %%
from matplotlib import font_manager

for _ttf in (Path(sys.prefix) / "fonts").glob("arial*.ttf"):
    font_manager.fontManager.addfont(str(_ttf))

cm = 1 / 2.54
plt.rcParams["svg.fonttype"] = "none"
plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.sans-serif"] = ["Arial"]

fontsize = 7
fontdict = dict(fontsize=fontsize)

CLUSTERS = ["sensory", "sustain", "motor"]

cond_colors = {
    "Passive": "#00753f",
    "Repeat": "#a9373b",
    "Decision": "#5c4ebd",
}

TASK_BIDS = {
    task: str(root)
    for task, root in DEFAULT_DATASETS.items()
    if task in {"LexicalDelay", "LexicalNoDelay"}
}
TASKS = ["LexicalDelay", "LexicalNoDelay"]
DESCRIPTIONS = ["Passive", "Repeat", "Decision"]
PHASES = ["stimulus", "delay", "go", "response"]

REF = "bipolar"
BAND = "highgamma"
MODALITY = "sound"
HEMI = None
EXCLUDE_SUBJECTS = {"D0121"}
TIME_MAX = 1.5

NMF_ASSIGNMENTS = nmf_assignments_path()
IMG_DIR = img_dir("fig3")

# %% [markdown]
# ## Helpers
#
# Copied from `notebooks/modulation.ipynb`, with current cluster keys.
#
# - Per subject: union of significant channels across conditions × phases
# - Intersect with NMF assignments so the same electrodes enter every curve
# - Trial-average `epoch(band)(zscore)` after `.pick`

# %%
def _norm_phase(phase: str) -> str:
    p = str(phase)
    if p == "Resp":
        p = "Response"
    elif p == "Audio":
        p = "Stimulus"
    return p.lower()


def _norm_subject(subject: str) -> str:
    return subject.removeprefix("sub-")


def _modality_of(path) -> str:
    return path.recording if path.recording is not None else "sound"


def epoch_root(bids_root: str) -> str:
    return str(Path(bids_root) / f"derivatives/epoch({REF})")


def load_assignments(path: Path | None = None) -> pd.DataFrame:
    path = Path(path) if path is not None else NMF_ASSIGNMENTS
    meta = pd.read_csv(path)
    required = {"subject", "channel", "functional_cluster"}
    missing = required - set(meta.columns)
    if missing:
        raise ValueError(f"{path} missing columns: {sorted(missing)}")
    meta = meta.copy()
    meta["subject"] = meta["subject"].map(_norm_subject)
    meta = meta[meta["functional_cluster"].isin(CLUSTERS)].copy()
    if HEMI is not None and "hemi" in meta.columns:
        meta = meta[meta["hemi"] == HEMI]
    meta = meta[~meta["subject"].isin(EXCLUDE_SUBJECTS)]
    meta = meta.drop_duplicates(subset=["subject", "channel"], keep="first")
    return meta.reset_index(drop=True)


def list_sig_paths(bids_root: str):
    return BIDSPath(
        root=epoch_root(bids_root),
        datatype="epoch(band)(sig)",
        suffix=BAND,
        extension=".h5",
        check=False,
    ).match()


def list_zscore_paths(bids_root: str):
    return BIDSPath(
        root=epoch_root(bids_root),
        datatype="epoch(band)(zscore)",
        suffix=BAND,
        extension=".h5",
        check=False,
    ).match()


def sig_union_by_subject(sig_paths, descriptions=DESCRIPTIONS) -> dict[str, set[str]]:
    by_subj: dict[str, set[str]] = defaultdict(set)
    for path in tqdm(sig_paths, desc="sig union"):
        if path.description not in descriptions:
            continue
        if _modality_of(path) != MODALITY:
            continue
        subj = _norm_subject(path.subject)
        if subj in EXCLUDE_SUBJECTS:
            continue
        epochs = mne.read_epochs(path, preload=False, verbose=False)
        by_subj[subj].update(epochs.ch_names)
    return dict(by_subj)


def evoked_to_long(epochs, channels: list[str]) -> pd.DataFrame | None:
    picks = [ch for ch in channels if ch in epochs.ch_names]
    if not picks:
        return None
    epo = epochs.copy().pick(picks)
    data = np.nanmean(epo.get_data(copy=False), axis=0)
    times = epo.times
    n_ch, n_t = data.shape
    return pd.DataFrame(
        {
            "time": np.tile(times, n_ch),
            "channel": np.repeat(list(epo.ch_names), n_t),
            "value": data.reshape(-1),
        }
    )


def load_task_waveforms(
    task: str,
    assignments: pd.DataFrame,
    *,
    descriptions=DESCRIPTIONS,
) -> tuple[pd.DataFrame, pd.DataFrame]:
    bids_root = TASK_BIDS[task]
    sig_paths = list_sig_paths(bids_root)
    z_paths = list_zscore_paths(bids_root)
    if not sig_paths or not z_paths:
        raise FileNotFoundError(f"{task}: missing sig/zscore epochs under {bids_root}")

    unions = sig_union_by_subject(sig_paths, descriptions=descriptions)
    assign_by_subj = {
        subj: set(g["channel"]) for subj, g in assignments.groupby("subject")
    }
    channel_cluster = assignments.set_index(["subject", "channel"])[
        "functional_cluster"
    ].to_dict()
    channel_hemi = (
        assignments.set_index(["subject", "channel"])["hemi"].to_dict()
        if "hemi" in assignments.columns
        else {}
    )

    qc_rows = []
    restricted: dict[str, list[str]] = {}
    for subj, chans in unions.items():
        keep = sorted(chans & assign_by_subj.get(subj, set()))
        restricted[subj] = keep
        row = {
            "task": task,
            "subject": subj,
            "n_sig_union": len(chans),
            "n_functional_union": len(keep),
        }
        for cluster in CLUSTERS:
            row[f"n_{cluster}"] = sum(
                1 for ch in keep if channel_cluster.get((subj, ch)) == cluster
            )
        qc_rows.append(row)
    qc = pd.DataFrame(qc_rows)

    rows = []
    for path in tqdm(z_paths, desc=f"zscore {task}"):
        if path.description not in descriptions:
            continue
        if _modality_of(path) != MODALITY:
            continue
        subj = _norm_subject(path.subject)
        if subj in EXCLUDE_SUBJECTS:
            continue
        picks = restricted.get(subj)
        if not picks:
            continue
        epochs = mne.read_epochs(path, preload=True, verbose=False)
        df = evoked_to_long(epochs, picks)
        del epochs
        if df is None or df.empty:
            continue
        df["subject"] = subj
        df["description"] = path.description
        df["task"] = task
        df["phase"] = _norm_phase(path.processing)
        df["modality"] = _modality_of(path)
        df["functional_cluster"] = [
            channel_cluster.get((subj, ch)) for ch in df["channel"]
        ]
        df["hemi"] = [channel_hemi.get((subj, ch)) for ch in df["channel"]]
        rows.append(df)

    if not rows:
        return pd.DataFrame(), qc
    out = pd.concat(rows, ignore_index=True)
    out = out[
        out["functional_cluster"].isin(CLUSTERS) & (out["time"] < TIME_MAX)
    ].copy()
    out["cluster_label"] = out["functional_cluster"].map(CLUSTER_LABELS)
    return out, qc


def load_zscore_subset(
    task: str,
    assignments: pd.DataFrame,
    restricted: dict[str, list[str]],
    *,
    descriptions: list[str],
    phases: list[str],
) -> pd.DataFrame:
    """Read selected zscore epochs, reusing an existing electrode restriction."""
    z_paths = list_zscore_paths(TASK_BIDS[task])
    phase_set = {_norm_phase(p) for p in phases}
    desc_set = set(descriptions)
    channel_cluster = assignments.set_index(["subject", "channel"])[
        "functional_cluster"
    ].to_dict()
    channel_hemi = (
        assignments.set_index(["subject", "channel"])["hemi"].to_dict()
        if "hemi" in assignments.columns
        else {}
    )
    rows = []
    label = f"zscore {task} {'/'.join(descriptions)} {'/'.join(phases)}"
    for path in tqdm(z_paths, desc=label):
        if path.description not in desc_set:
            continue
        if _norm_phase(path.processing) not in phase_set:
            continue
        if _modality_of(path) != MODALITY:
            continue
        subj = _norm_subject(path.subject)
        if subj in EXCLUDE_SUBJECTS:
            continue
        picks = restricted.get(subj)
        if not picks:
            continue
        epochs = mne.read_epochs(path, preload=True, verbose=False)
        df = evoked_to_long(epochs, picks)
        del epochs
        if df is None or df.empty:
            continue
        df["subject"] = subj
        df["description"] = path.description
        df["task"] = task
        df["phase"] = _norm_phase(path.processing)
        df["modality"] = _modality_of(path)
        df["functional_cluster"] = [
            channel_cluster.get((subj, ch)) for ch in df["channel"]
        ]
        df["hemi"] = [channel_hemi.get((subj, ch)) for ch in df["channel"]]
        rows.append(df)
    if not rows:
        return pd.DataFrame()
    out = pd.concat(rows, ignore_index=True)
    out = out[
        out["functional_cluster"].isin(CLUSTERS) & (out["time"] < TIME_MAX)
    ].copy()
    out["cluster_label"] = out["functional_cluster"].map(CLUSTER_LABELS)
    return out

# %% [markdown]
# ## Load waveforms
#
# Heavy: reads `epoch(band)(sig)` then z-scored epochs. Use a compute node.

# %%
assignments = load_assignments()
print(
    f"NMF assignments: {len(assignments):,} | "
    f"subjects={assignments.subject.nunique()} | "
    + " | ".join(
        f"{CLUSTER_LABELS[c]}={int((assignments.functional_cluster == c).sum())}"
        for c in CLUSTERS
    )
)

hga_parts = []
qc_parts = []
for task in TASKS:
    print(f"\n=== {task} ===")
    part, qc = load_task_waveforms(task, assignments)
    n_subj = part.subject.nunique() if len(part) else 0
    conds = sorted(part.description.unique()) if len(part) else []
    print(f"  rows={len(part):,} | subjects={n_subj} | conditions={conds}")
    if len(part):
        hga_parts.append(part)
    if len(qc):
        qc_parts.append(qc)

HGAs = pd.concat(hga_parts, ignore_index=True) if hga_parts else pd.DataFrame()
union_qc = pd.concat(qc_parts, ignore_index=True) if qc_parts else pd.DataFrame()
print(f"\nTotal rows: {len(HGAs):,}")
if len(HGAs):
    print("Tasks:", sorted(HGAs.task.unique()))
    print("Descriptions:", sorted(HGAs.description.unique()))
    print("Phases:", sorted(HGAs.phase.unique()))
    for c in CLUSTERS:
        n = HGAs.loc[HGAs.functional_cluster == c, "channel"].nunique()
        print(f"{CLUSTER_LABELS[c]} channels: {n}")
# Out:
# NMF assignments: 255 | subjects=63 | sensory=39 | sustained=80 | motor=136
#
# === LexicalDelay ===
# sig union:   0%|          | 0/416 [00:00<?, ?it/s]
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0023/epoch(band)(sig)/sub-D0023_proc-Delay_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0023/epoch(band)(sig)/sub-D0023_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0023/epoch(band)(sig)/sub-D0023_proc-Go_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0023/epoch(band)(sig)/sub-D0023_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0023/epoch(band)(sig)/sub-D0023_proc-Response_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0023/epoch(band)(sig)/sub-D0023_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0023/epoch(band)(sig)/sub-D0023_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0023/epoch(band)(sig)/sub-D0023_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0024/epoch(band)(sig)/sub-D0024_proc-Delay_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0024/epoch(band)(sig)/sub-D0024_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0024/epoch(band)(sig)/sub-D0024_proc-Go_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0024/epoch(band)(sig)/sub-D0024_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0024/epoch(band)(sig)/sub-D0024_proc-Response_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0024/epoch(band)(sig)/sub-D0024_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0024/epoch(band)(sig)/sub-D0024_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0024/epoch(band)(sig)/sub-D0024_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0026/epoch(band)(sig)/sub-D0026_proc-Delay_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0026/epoch(band)(sig)/sub-D0026_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0026/epoch(band)(sig)/sub-D0026_proc-Go_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0026/epoch(band)(sig)/sub-D0026_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0026/epoch(band)(sig)/sub-D0026_proc-Response_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0026/epoch(band)(sig)/sub-D0026_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0026/epoch(band)(sig)/sub-D0026_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0026/epoch(band)(sig)/sub-D0026_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0027/epoch(band)(sig)/sub-D0027_proc-Delay_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0027/epoch(band)(sig)/sub-D0027_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0027/epoch(band)(sig)/sub-D0027_proc-Go_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0027/epoch(band)(sig)/sub-D0027_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0027/epoch(band)(sig)/sub-D0027_proc-Response_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0027/epoch(band)(sig)/sub-D0027_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0027/epoch(band)(sig)/sub-D0027_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0027/epoch(band)(sig)/sub-D0027_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0028/epoch(band)(sig)/sub-D0028_proc-Delay_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0028/epoch(band)(sig)/sub-D0028_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0028/epoch(band)(sig)/sub-D0028_proc-Go_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0028/epoch(band)(sig)/sub-D0028_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0028/epoch(band)(sig)/sub-D0028_proc-Response_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0028/epoch(band)(sig)/sub-D0028_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0028/epoch(band)(sig)/sub-D0028_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0028/epoch(band)(sig)/sub-D0028_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0029/epoch(band)(sig)/sub-D0029_proc-Delay_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0029/epoch(band)(sig)/sub-D0029_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0029/epoch(band)(sig)/sub-D0029_proc-Go_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0029/epoch(band)(sig)/sub-D0029_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0029/epoch(band)(sig)/sub-D0029_proc-Response_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0029/epoch(band)(sig)/sub-D0029_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0029/epoch(band)(sig)/sub-D0029_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0029/epoch(band)(sig)/sub-D0029_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0032/epoch(band)(sig)/sub-D0032_proc-Delay_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0032/epoch(band)(sig)/sub-D0032_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0032/epoch(band)(sig)/sub-D0032_proc-Go_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0032/epoch(band)(sig)/sub-D0032_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0032/epoch(band)(sig)/sub-D0032_proc-Response_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0032/epoch(band)(sig)/sub-D0032_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0032/epoch(band)(sig)/sub-D0032_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0032/epoch(band)(sig)/sub-D0032_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0035/epoch(band)(sig)/sub-D0035_proc-Delay_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0035/epoch(band)(sig)/sub-D0035_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0035/epoch(band)(sig)/sub-D0035_proc-Go_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0035/epoch(band)(sig)/sub-D0035_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0035/epoch(band)(sig)/sub-D0035_proc-Response_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0035/epoch(band)(sig)/sub-D0035_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0035/epoch(band)(sig)/sub-D0035_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0035/epoch(band)(sig)/sub-D0035_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0038/epoch(band)(sig)/sub-D0038_proc-Delay_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0038/epoch(band)(sig)/sub-D0038_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0038/epoch(band)(sig)/sub-D0038_proc-Go_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0038/epoch(band)(sig)/sub-D0038_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0038/epoch(band)(sig)/sub-D0038_proc-Response_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0038/epoch(band)(sig)/sub-D0038_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0038/epoch(band)(sig)/sub-D0038_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0038/epoch(band)(sig)/sub-D0038_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0042/epoch(band)(sig)/sub-D0042_proc-Delay_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0042/epoch(band)(sig)/sub-D0042_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0042/epoch(band)(sig)/sub-D0042_proc-Go_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0042/epoch(band)(sig)/sub-D0042_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0042/epoch(band)(sig)/sub-D0042_proc-Response_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0042/epoch(band)(sig)/sub-D0042_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0042/epoch(band)(sig)/sub-D0042_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0042/epoch(band)(sig)/sub-D0042_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0044/epoch(band)(sig)/sub-D0044_proc-Delay_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0044/epoch(band)(sig)/sub-D0044_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0044/epoch(band)(sig)/sub-D0044_proc-Go_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0044/epoch(band)(sig)/sub-D0044_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0044/epoch(band)(sig)/sub-D0044_proc-Response_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0044/epoch(band)(sig)/sub-D0044_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0044/epoch(band)(sig)/sub-D0044_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0044/epoch(band)(sig)/sub-D0044_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0047/epoch(band)(sig)/sub-D0047_proc-Delay_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0047/epoch(band)(sig)/sub-D0047_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0047/epoch(band)(sig)/sub-D0047_proc-Go_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0047/epoch(band)(sig)/sub-D0047_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0047/epoch(band)(sig)/sub-D0047_proc-Response_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0047/epoch(band)(sig)/sub-D0047_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0047/epoch(band)(sig)/sub-D0047_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0047/epoch(band)(sig)/sub-D0047_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0053/epoch(band)(sig)/sub-D0053_proc-Delay_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0053/epoch(band)(sig)/sub-D0053_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0053/epoch(band)(sig)/sub-D0053_proc-Go_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0053/epoch(band)(sig)/sub-D0053_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0053/epoch(band)(sig)/sub-D0053_proc-Response_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0053/epoch(band)(sig)/sub-D0053_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0053/epoch(band)(sig)/sub-D0053_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0053/epoch(band)(sig)/sub-D0053_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0054/epoch(band)(sig)/sub-D0054_proc-Delay_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0054/epoch(band)(sig)/sub-D0054_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0054/epoch(band)(sig)/sub-D0054_proc-Go_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepDelay/BIDS/derivatives/epoch(bipolar)/sub-D0054/epoch(band)(sig)/sub-D0054_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# ...
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0090/epoch(band)(zscore)/sub-D0090_task-LexicalNoDelay_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0090/epoch(band)(zscore)/sub-D0090_task-LexicalNoDelay_proc-Stimulus_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0090/epoch(band)(zscore)/sub-D0090_task-LexicalNoDelay_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0092/epoch(band)(zscore)/sub-D0092_task-LexicalNoDelay_proc-Response_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0092/epoch(band)(zscore)/sub-D0092_task-LexicalNoDelay_proc-Response_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0092/epoch(band)(zscore)/sub-D0092_task-LexicalNoDelay_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0092/epoch(band)(zscore)/sub-D0092_task-LexicalNoDelay_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0092/epoch(band)(zscore)/sub-D0092_task-LexicalNoDelay_proc-Stimulus_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0092/epoch(band)(zscore)/sub-D0092_task-LexicalNoDelay_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0094/epoch(band)(zscore)/sub-D0094_task-LexicalNoDelay_proc-Response_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0094/epoch(band)(zscore)/sub-D0094_task-LexicalNoDelay_proc-Response_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0094/epoch(band)(zscore)/sub-D0094_task-LexicalNoDelay_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0094/epoch(band)(zscore)/sub-D0094_task-LexicalNoDelay_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0094/epoch(band)(zscore)/sub-D0094_task-LexicalNoDelay_proc-Stimulus_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0094/epoch(band)(zscore)/sub-D0094_task-LexicalNoDelay_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0137/epoch(band)(zscore)/sub-D0137_task-LexicalNoDelay_proc-Response_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0137/epoch(band)(zscore)/sub-D0137_task-LexicalNoDelay_proc-Response_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0137/epoch(band)(zscore)/sub-D0137_task-LexicalNoDelay_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0137/epoch(band)(zscore)/sub-D0137_task-LexicalNoDelay_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0137/epoch(band)(zscore)/sub-D0137_task-LexicalNoDelay_proc-Stimulus_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0137/epoch(band)(zscore)/sub-D0137_task-LexicalNoDelay_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0138/epoch(band)(zscore)/sub-D0138_task-LexicalNoDelay_proc-Response_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0138/epoch(band)(zscore)/sub-D0138_task-LexicalNoDelay_proc-Response_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0138/epoch(band)(zscore)/sub-D0138_task-LexicalNoDelay_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0138/epoch(band)(zscore)/sub-D0138_task-LexicalNoDelay_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0138/epoch(band)(zscore)/sub-D0138_task-LexicalNoDelay_proc-Stimulus_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0138/epoch(band)(zscore)/sub-D0138_task-LexicalNoDelay_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0139/epoch(band)(zscore)/sub-D0139_task-LexicalNoDelay_proc-Response_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0139/epoch(band)(zscore)/sub-D0139_task-LexicalNoDelay_proc-Response_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0139/epoch(band)(zscore)/sub-D0139_task-LexicalNoDelay_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0139/epoch(band)(zscore)/sub-D0139_task-LexicalNoDelay_proc-Stimulus_desc-Decision_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0139/epoch(band)(zscore)/sub-D0139_task-LexicalNoDelay_proc-Stimulus_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.0_LexicalDecRepNoDelay/BIDS/derivatives/epoch(bipolar)/sub-D0139/epoch(band)(zscore)/sub-D0139_task-LexicalNoDelay_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
#   rows=86,400 | subjects=15 | conditions=['Decision', 'Passive', 'Repeat']
#
# Total rows: 478,080
# Tasks: ['LexicalDelay', 'LexicalNoDelay']
# Descriptions: ['Decision', 'Passive', 'Repeat']
# Phases: ['delay', 'go', 'response', 'stimulus']
# sensory channels: 24
# sustained channels: 50
# motor channels: 80

# %%
plot_df = HGAs.copy()

if len(union_qc):
    qc_cols = ["n_sig_union", "n_functional_union"] + [f"n_{c}" for c in CLUSTERS]
    display_qc = (
        union_qc.groupby("task", observed=True)[qc_cols]
        .mean()
        .round(1)
        .reindex(TASKS)
    )
    print("Mean per-subject union sizes:")
    display(display_qc)

if len(plot_df):
    coverage = (
        plot_df.groupby(
            ["task", "description", "functional_cluster"], observed=True
        )["channel"]
        .nunique()
        .unstack(["description", "functional_cluster"])
        .reindex(TASKS)
    )
    col_order = [(d, c) for d in DESCRIPTIONS for c in CLUSTERS]
    coverage = coverage.reindex(columns=pd.MultiIndex.from_tuples(col_order))
    coverage = coverage.fillna(0).astype(int)
    print(f"\nPlot rows: {len(plot_df):,} | subjects: {plot_df.subject.nunique()}")
    display(coverage)
else:
    print("No plot rows loaded.")
# Out:
# Mean per-subject union sizes:
#                 n_sig_union  n_functional_union  n_sensory  n_sustain  n_motor
# task
# LexicalDelay          101.5                 3.0        0.5        1.0      1.5
# LexicalNoDelay         84.9                 2.0        0.2        1.0      0.8
# Plot rows: 478,080 | subjects: 38
#                Passive                Repeat               Decision          \
#                sensory sustain motor sensory sustain motor  sensory sustain
# task
# LexicalDelay         0       0     0      24      50    79       24      50
# LexicalNoDelay       4      22    19       4      22    19        4      22
#
#
#                motor
# task
# LexicalDelay      79
# LexicalNoDelay    19

# %% [markdown]
# ## 1. Condition waveforms
#
# Green Passive / red Repeat / purple Decision. Rows are clusters in
# sensory → sustain → motor.
#
# Working hypothesis from the old AIC result: **sustain** should show Decision > Repeat
# and little Passive. Sensory more stimulus-locked; motor more Repeat-like at response.

# %%
def _style_axes(ax, *, ylim=(-0.1, 0.6), hide_left: bool = True) -> None:
    ax.axvline(x=0, color="k", linestyle="--", linewidth=0.5)
    ax.axhline(y=0, color="k", linestyle="--", linewidth=0.5)
    ax.tick_params(labelsize=fontsize, width=0.75, length=2, which="both")
    plt.setp(ax.spines.values(), linewidth=0.75)
    sns.despine(ax=ax, offset=1, trim=True)
    ax.set_ylim(*ylim)
    if hide_left:
        ax.set_yticklabels([])
        ax.set_yticks([])
        ax.spines["left"].set_visible(False)


def plot_condition_waveforms(
    df: pd.DataFrame,
    *,
    clusters=CLUSTERS,
    phases=PHASES,
    descriptions=DESCRIPTIONS,
    title: str | None = None,
    ylim=(-0.1, 0.5),
    save_name: str | None = None,
):
    n_rows, n_cols = len(clusters), len(phases)
    fig, axes = plt.subplots(
        nrows=n_rows,
        ncols=n_cols,
        figsize=(2.2 * n_cols * cm, 2.4 * n_rows * cm),
        sharey="row",
        squeeze=False,
    )
    plt.subplots_adjust(wspace=0.05, hspace=0.35)

    for row, cluster in enumerate(clusters):
        cluster_df = df[df["functional_cluster"] == cluster]
        label = CLUSTER_LABELS.get(cluster, cluster)
        for col, phase in enumerate(phases):
            ax = axes[row, col]
            phase_df = cluster_df[cluster_df["phase"] == phase]
            present = [d for d in descriptions if (phase_df["description"] == d).any()]
            if phase_df.empty or not present:
                ax.text(
                    0.5,
                    0.5,
                    "n/a",
                    ha="center",
                    va="center",
                    fontsize=fontsize,
                    transform=ax.transAxes,
                    color="0.6",
                )
            else:
                legend = row == 0 and col == n_cols - 1
                sns.lineplot(
                    data=phase_df,
                    x="time",
                    y="value",
                    hue="description",
                    hue_order=present,
                    ax=ax,
                    palette=[cond_colors[d] for d in present],
                    legend=legend,
                    lw=1,
                    errorbar=("ci", 95),
                )
                if legend and ax.get_legend() is not None:
                    ax.legend(title="", fontsize=fontsize, frameon=False)
                elif ax.get_legend() is not None:
                    ax.get_legend().remove()
            _style_axes(ax, ylim=ylim, hide_left=(col != 0))
            ax.set_xlabel(f"{phase.capitalize()} (s)" if row == n_rows - 1 else "", fontsize=fontsize)
            ax.set_ylabel(f"{label}\nHGA (z)" if col == 0 else "", fontsize=fontsize)

    if title:
        fig.suptitle(title, fontsize=fontsize, y=1.02)
    if save_name:
        out = save_svg(fig, IMG_DIR / save_name)
        print("Wrote", out)
    plt.show()
    return fig


def plot_spotlight_waveforms(
    df: pd.DataFrame,
    spotlights: list[dict],
    *,
    descriptions=DESCRIPTIONS,
    ylim=(-0.1, 0.5),
    title: str | None = None,
    save_name: str | None = None,
):
    widths = [max(len(s["phases"]), 1) for s in spotlights]
    fig, axes = plt.subplots(
        nrows=1,
        ncols=sum(widths),
        figsize=(2.4 * sum(widths) * cm, 2.8 * cm),
        sharey=True,
        squeeze=False,
    )
    plt.subplots_adjust(wspace=0.12)
    flat = axes[0]
    col_i = 0
    for spot_i, spec in enumerate(spotlights):
        cluster = spec["cluster"]
        phases = list(spec["phases"])
        claim = spec.get("title", CLUSTER_LABELS.get(cluster, cluster))
        cluster_df = df[df["functional_cluster"] == cluster]
        for j, phase in enumerate(phases):
            ax = flat[col_i]
            phase_df = cluster_df[cluster_df["phase"] == phase]
            present = [d for d in descriptions if (phase_df["description"] == d).any()]
            legend = spot_i == len(spotlights) - 1 and j == len(phases) - 1
            if phase_df.empty or not present:
                ax.text(
                    0.5,
                    0.5,
                    "n/a",
                    ha="center",
                    va="center",
                    fontsize=fontsize,
                    transform=ax.transAxes,
                    color="0.6",
                )
            else:
                sns.lineplot(
                    data=phase_df,
                    x="time",
                    y="value",
                    hue="description",
                    hue_order=present,
                    ax=ax,
                    palette=[cond_colors[d] for d in present],
                    legend=legend,
                    lw=1,
                    errorbar=("ci", 95),
                )
                if legend and ax.get_legend() is not None:
                    ax.legend(title="", fontsize=fontsize, frameon=False)
                elif ax.get_legend() is not None:
                    ax.get_legend().remove()
            _style_axes(ax, ylim=ylim, hide_left=(col_i != 0))
            ax.set_xlabel(f"{phase.capitalize()} (s)", fontsize=fontsize)
            ax.set_ylabel(f"{claim}\nHGA (z)" if j == 0 else "", fontsize=fontsize)
            col_i += 1
    if title:
        fig.suptitle(title, fontsize=fontsize, y=1.05)
    if save_name:
        out = save_svg(fig, IMG_DIR / save_name)
        print("Wrote", out)
    plt.show()
    return fig

# %%
if plot_df.empty:
    print("Nothing to plot — run the load cell on a compute node.")
else:
    ld = plot_df[plot_df.task == "LexicalDelay"]
    plot_condition_waveforms(
        ld,
        save_name="fig3_context_LexicalDelay",
        title=f"LexicalDelay | Repeat vs Decision | n={ld.subject.nunique()} subjects",
    )
    plot_condition_waveforms(
        ld,
        phases=["stimulus", "response"],
        save_name="fig3_context_LexicalDelay_stim_resp",
        title=(
            f"LexicalDelay | stimulus + response | "
            f"n={ld.subject.nunique()} subjects"
        ),
    )
# Out:
# Wrote /hpc/group/coganlab/nanlinshi/insula-functional/img/fig3/fig3_context_LexicalDelay.svg
# Wrote /hpc/group/coganlab/nanlinshi/insula-functional/img/fig3/fig3_context_LexicalDelay_stim_resp.svg

# %%
if plot_df.empty:
    print("Nothing to plot.")
else:
    lnd = plot_df[plot_df.task == "LexicalNoDelay"]
    plot_condition_waveforms(
        lnd,
        save_name="fig3_context_LexicalNoDelay",
        title=f"LexicalNoDelay | Passive / Repeat / Decision | n={lnd.subject.nunique()} subjects",
    )
# Out:
# Wrote /hpc/group/coganlab/nanlinshi/insula-functional/img/fig3/fig3_context_LexicalNoDelay.svg

# %% [markdown]
# ## Pooled conditions (all datasets)
#
# Same 3 × 2 layout (cluster × stimulus / response), but each hue is **pooled
# across every dataset that has that condition**. PictureNaming is **sound
# only**. SentenceRep is left out.
#
# | Condition | Tasks |
# |-----------|-------|
# | Passive | LexicalNoDelay, PictureNaming |
# | Repeat | LexicalDelay, LexicalNoDelay, PictureNaming, PhonemeSequence |
# | Decision | LexicalDelay, LexicalNoDelay |
#
# Run the extra-load cell on a compute node. Delay / NoDelay waveforms above
# do not need to be re-run if `plot_df` is already in memory.

# %%
CONDITION_TASKS = {
    "Passive": ["LexicalNoDelay", "PictureNaming"],
    "Repeat": ["LexicalDelay", "LexicalNoDelay", "PictureNaming", "PhonemeSequence"],
    "Decision": ["LexicalDelay", "LexicalNoDelay"],
}
EXTRA_TASKS = ["PhonemeSequence", "PictureNaming"]
TASK_BIDS.update({task: str(DEFAULT_DATASETS[task]) for task in EXTRA_TASKS})

if "assignments" not in dir() or "plot_df" not in dir():
    raise RuntimeError("Run the helpers + Delay/NoDelay load cells first.")

# Keep previously concatenated extra tasks if the kernel still has them.
if "all_hga" in dir() and len(all_hga):
    working = all_hga.copy()
elif "pooled_df" in dir() and len(pooled_df):
    extra_only = pooled_df[pooled_df["task"].isin(EXTRA_TASKS)]
    working = (
        pd.concat([plot_df, extra_only], ignore_index=True)
        if len(extra_only)
        else plot_df.copy()
    )
else:
    working = plot_df.copy()
already = set(working.task.unique()) if len(working) else set()

extra_parts = []
extra_qc_parts = []
for task in EXTRA_TASKS:
    if task in already:
        print(f"skip {task} (already loaded)")
        continue
    print(f"\n=== {task} ===")
    part, qc = load_task_waveforms(task, assignments)
    n_subj = part.subject.nunique() if len(part) else 0
    conds = sorted(part.description.unique()) if len(part) else []
    phases_present = sorted(part.phase.unique()) if len(part) else []
    print(f"  rows={len(part):,} | subjects={n_subj} | conditions={conds} | phases={phases_present}")
    if len(part):
        extra_parts.append(part)
        already.add(task)
    if len(qc):
        extra_qc_parts.append(qc)

if extra_parts:
    working = pd.concat([working, *extra_parts], ignore_index=True)

# SHI-58: splice PictureNaming Passive Response onto the existing electrode set.
# Do not rebuild sig-union; that would change which channels enter the other phases.
pn = working[working["task"] == "PictureNaming"] if len(working) else pd.DataFrame()
if pn.empty:
    print("PictureNaming is not loaded — cannot append Passive Response.")
else:
    restricted = {
        subj: sorted(g["channel"].unique())
        for subj, g in pn.groupby("subject")
    }
    print(
        f"\n=== PictureNaming Passive response (append, "
        f"n_subjects={len(restricted)}) ==="
    )
    pn_resp = load_zscore_subset(
        "PictureNaming",
        assignments,
        restricted,
        descriptions=["Passive"],
        phases=["response"],
    )
    print(
        "  Passive response: "
        f"subjects={pn_resp.subject.nunique() if len(pn_resp) else 0} | "
        f"rows={len(pn_resp):,}"
    )
    drop = (
        (working["task"] == "PictureNaming")
        & (working["description"] == "Passive")
        & (working["phase"] == "response")
    )
    working = working.loc[~drop].copy()
    if len(pn_resp):
        working = pd.concat([working, pn_resp], ignore_index=True)

all_hga = working
pooled_parts = []
for cond, tasks in CONDITION_TASKS.items():
    chunk = all_hga[
        (all_hga["description"] == cond) & (all_hga["task"].isin(tasks))
    ]
    print(
        f"{cond}: tasks={sorted(chunk.task.unique()) if len(chunk) else []} | "
        f"subjects={chunk.subject.nunique() if len(chunk) else 0} | "
        f"rows={len(chunk):,}"
    )
    if len(chunk):
        pooled_parts.append(chunk)

pooled_df = pd.concat(pooled_parts, ignore_index=True) if pooled_parts else pd.DataFrame()
print(
    f"\npooled rows={len(pooled_df):,} | "
    f"subjects={pooled_df.subject.nunique() if len(pooled_df) else 0}"
)
if len(pooled_df):
    resp_passive = pooled_df[
        (pooled_df["phase"] == "response")
        & (pooled_df["description"] == "Passive")
        & (pooled_df["task"] != "LexicalNoDelay")
    ]
    print(
        "response Passive tasks:",
        sorted(resp_passive.task.unique()) if len(resp_passive) else [],
        "| subjects:",
        resp_passive.subject.nunique() if len(resp_passive) else 0,
    )
    coverage = (
        pooled_df.groupby(["description", "functional_cluster"], observed=True)["channel"]
        .nunique()
        .unstack("functional_cluster")
        .reindex(list(CONDITION_TASKS))
        .reindex(columns=CLUSTERS)
        .fillna(0)
        .astype(int)
    )
    display(coverage)
# Out:
# === PhonemeSequence ===
# sig union:   0%|          | 0/194 [00:00<?, ?it/s]
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0019/epoch(band)(sig)/sub-D0019_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0019/epoch(band)(sig)/sub-D0019_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0019/epoch(band)(sig)/sub-D0019_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0022/epoch(band)(sig)/sub-D0022_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0022/epoch(band)(sig)/sub-D0022_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0022/epoch(band)(sig)/sub-D0022_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0023/epoch(band)(sig)/sub-D0023_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0023/epoch(band)(sig)/sub-D0023_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0023/epoch(band)(sig)/sub-D0023_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0023/epoch(band)(sig)/sub-D0023_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0024/epoch(band)(sig)/sub-D0024_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0024/epoch(band)(sig)/sub-D0024_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0024/epoch(band)(sig)/sub-D0024_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0024/epoch(band)(sig)/sub-D0024_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0025/epoch(band)(sig)/sub-D0025_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0025/epoch(band)(sig)/sub-D0025_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0025/epoch(band)(sig)/sub-D0025_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0025/epoch(band)(sig)/sub-D0025_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0028/epoch(band)(sig)/sub-D0028_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0028/epoch(band)(sig)/sub-D0028_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0028/epoch(band)(sig)/sub-D0028_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0028/epoch(band)(sig)/sub-D0028_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0029/epoch(band)(sig)/sub-D0029_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0029/epoch(band)(sig)/sub-D0029_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0029/epoch(band)(sig)/sub-D0029_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0029/epoch(band)(sig)/sub-D0029_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0031/epoch(band)(sig)/sub-D0031_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0031/epoch(band)(sig)/sub-D0031_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0031/epoch(band)(sig)/sub-D0031_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0031/epoch(band)(sig)/sub-D0031_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0035/epoch(band)(sig)/sub-D0035_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0035/epoch(band)(sig)/sub-D0035_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0035/epoch(band)(sig)/sub-D0035_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0035/epoch(band)(sig)/sub-D0035_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0040/epoch(band)(sig)/sub-D0040_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0040/epoch(band)(sig)/sub-D0040_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0040/epoch(band)(sig)/sub-D0040_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0040/epoch(band)(sig)/sub-D0040_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0041/epoch(band)(sig)/sub-D0041_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0041/epoch(band)(sig)/sub-D0041_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0041/epoch(band)(sig)/sub-D0041_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0041/epoch(band)(sig)/sub-D0041_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0042/epoch(band)(sig)/sub-D0042_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0042/epoch(band)(sig)/sub-D0042_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0042/epoch(band)(sig)/sub-D0042_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0042/epoch(band)(sig)/sub-D0042_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0045/epoch(band)(sig)/sub-D0045_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0045/epoch(band)(sig)/sub-D0045_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0045/epoch(band)(sig)/sub-D0045_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0045/epoch(band)(sig)/sub-D0045_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0049/epoch(band)(sig)/sub-D0049_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0049/epoch(band)(sig)/sub-D0049_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0049/epoch(band)(sig)/sub-D0049_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0049/epoch(band)(sig)/sub-D0049_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0052/epoch(band)(sig)/sub-D0052_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0052/epoch(band)(sig)/sub-D0052_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0052/epoch(band)(sig)/sub-D0052_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0052/epoch(band)(sig)/sub-D0052_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0053/epoch(band)(sig)/sub-D0053_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0053/epoch(band)(sig)/sub-D0053_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0053/epoch(band)(sig)/sub-D0053_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0053/epoch(band)(sig)/sub-D0053_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0054/epoch(band)(sig)/sub-D0054_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0054/epoch(band)(sig)/sub-D0054_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0054/epoch(band)(sig)/sub-D0054_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0054/epoch(band)(sig)/sub-D0054_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0055/epoch(band)(sig)/sub-D0055_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0055/epoch(band)(sig)/sub-D0055_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0055/epoch(band)(sig)/sub-D0055_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0055/epoch(band)(sig)/sub-D0055_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0056/epoch(band)(sig)/sub-D0056_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0056/epoch(band)(sig)/sub-D0056_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0056/epoch(band)(sig)/sub-D0056_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0056/epoch(band)(sig)/sub-D0056_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0057/epoch(band)(sig)/sub-D0057_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0057/epoch(band)(sig)/sub-D0057_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0057/epoch(band)(sig)/sub-D0057_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0057/epoch(band)(sig)/sub-D0057_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0058/epoch(band)(sig)/sub-D0058_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0058/epoch(band)(sig)/sub-D0058_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0058/epoch(band)(sig)/sub-D0058_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0058/epoch(band)(sig)/sub-D0058_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0059/epoch(band)(sig)/sub-D0059_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0059/epoch(band)(sig)/sub-D0059_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0059/epoch(band)(sig)/sub-D0059_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0059/epoch(band)(sig)/sub-D0059_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0060/epoch(band)(sig)/sub-D0060_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0060/epoch(band)(sig)/sub-D0060_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0060/epoch(band)(sig)/sub-D0060_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0060/epoch(band)(sig)/sub-D0060_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0061/epoch(band)(sig)/sub-D0061_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0061/epoch(band)(sig)/sub-D0061_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0061/epoch(band)(sig)/sub-D0061_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0061/epoch(band)(sig)/sub-D0061_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0063/epoch(band)(sig)/sub-D0063_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0063/epoch(band)(sig)/sub-D0063_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0063/epoch(band)(sig)/sub-D0063_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0063/epoch(band)(sig)/sub-D0063_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0064/epoch(band)(sig)/sub-D0064_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0064/epoch(band)(sig)/sub-D0064_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0064/epoch(band)(sig)/sub-D0064_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0064/epoch(band)(sig)/sub-D0064_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0066/epoch(band)(sig)/sub-D0066_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0066/epoch(band)(sig)/sub-D0066_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0066/epoch(band)(sig)/sub-D0066_proc-Response_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0066/epoch(band)(sig)/sub-D0066_proc-Stimulus_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0067/epoch(band)(sig)/sub-D0067_proc-Delay_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:69: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.4_Phoneme_sequencing/BIDS/derivatives/epoch(bipolar)/sub-D0067/epoch(band)(sig)/sub-D0067_proc-Go_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=False, verbose=False)
# ...
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0139/epoch(band)(zscore)/sub-D0139_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0139/epoch(band)(zscore)/sub-D0139_task-PictureNaming_proc-Response_recording-sound_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0139/epoch(band)(zscore)/sub-D0139_task-PictureNaming_proc-Stimulus_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:146: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0139/epoch(band)(zscore)/sub-D0139_task-PictureNaming_proc-Stimulus_recording-sound_desc-Repeat_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
#   rows=289,280 | subjects=27 | conditions=['Passive', 'Repeat'] | phases=['delay', 'go', 'response', 'stimulus']
#
# === PictureNaming Passive response (append, n_subjects=27) ===
# zscore PictureNaming Passive response:   0%|          | 0/888 [00:00<?, ?it/s]
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0079/epoch(band)(zscore)/sub-D0079_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0080/epoch(band)(zscore)/sub-D0080_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0081/epoch(band)(zscore)/sub-D0081_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0084/epoch(band)(zscore)/sub-D0084_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0085/epoch(band)(zscore)/sub-D0085_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0086/epoch(band)(zscore)/sub-D0086_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0088/epoch(band)(zscore)/sub-D0088_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0090/epoch(band)(zscore)/sub-D0090_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0091/epoch(band)(zscore)/sub-D0091_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0092/epoch(band)(zscore)/sub-D0092_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0093/epoch(band)(zscore)/sub-D0093_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0094/epoch(band)(zscore)/sub-D0094_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0096/epoch(band)(zscore)/sub-D0096_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0102/epoch(band)(zscore)/sub-D0102_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0105/epoch(band)(zscore)/sub-D0105_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0107/epoch(band)(zscore)/sub-D0107_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0108/epoch(band)(zscore)/sub-D0108_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0118/epoch(band)(zscore)/sub-D0118_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0119/epoch(band)(zscore)/sub-D0119_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0123/epoch(band)(zscore)/sub-D0123_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0125/epoch(band)(zscore)/sub-D0125_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0129/epoch(band)(zscore)/sub-D0129_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0131/epoch(band)(zscore)/sub-D0131_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0134/epoch(band)(zscore)/sub-D0134_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0137/epoch(band)(zscore)/sub-D0137_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0138/epoch(band)(zscore)/sub-D0138_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
# /hpc/home/ns458/coganlab/nanlinshi/tmp/ipykernel_1887727/2093882390.py:207: RuntimeWarning: This filename (/cwork/ns458/BIDS-1.3_PictureNaming/BIDS/derivatives/epoch(bipolar)/sub-D0139/epoch(band)(zscore)/sub-D0139_task-PictureNaming_proc-Response_recording-sound_desc-Passive_highgamma.h5) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True, verbose=False)
#   Passive response: subjects=27 | rows=36,160
# Passive: tasks=['LexicalNoDelay', 'PictureNaming'] | subjects=35 | rows=173,440
# Repeat: tasks=['LexicalDelay', 'LexicalNoDelay', 'PhonemeSequence', 'PictureNaming'] | subjects=62 | rows=501,120
# Decision: tasks=['LexicalDelay', 'LexicalNoDelay'] | subjects=38 | rows=224,640
#
# pooled rows=899,200 | subjects=62
# response Passive tasks: ['PictureNaming'] | subjects: 27
# functional_cluster  sensory  sustain  motor
# description
# Passive                  17       53     67
# Repeat                   38       79    133
# Decision                 24       50     80

# %%
from matplotlib.colors import to_hex, to_rgb

phases = ["stimulus", "delay", "response"]
descriptions = ["Passive", "Repeat", "Decision"]
ylim = (-0.1, 0.7)
n_rows, n_cols = len(CLUSTERS), len(phases)


def mix_hex(color, other, amount):
    a = np.asarray(to_rgb(color))
    b = np.asarray(to_rgb(other))
    return to_hex(a * (1.0 - amount) + b * amount)


def cluster_condition_palette(cluster_color, present):
    shades = {
        "Passive": "black",
        "Repeat": cluster_color,
        "Decision": mix_hex(cluster_color, "black", 0.28),
    }
    return [shades[d] for d in present]

resp_passive = pooled_df[
    (pooled_df["phase"] == "response")
    & (pooled_df["description"] == "Passive")
    & (pooled_df["task"] != "LexicalNoDelay")
]
print(
    "response Passive tasks:",
    sorted(resp_passive.task.unique()) if len(resp_passive) else [],
    "| subjects:",
    resp_passive.subject.nunique() if len(resp_passive) else 0,
)

# Outlier Passive-response electrodes (large peak / temporal variance).
DROP_CHANNELS = {
    "D0125_LTMS3-4",
    "D0125_LTMS2-3",
    "D0125_LTMS1-2",
    "D0129_LFAI2-3",
}
fig_df = pooled_df[~pooled_df["channel"].isin(DROP_CHANNELS)].copy()
delay_passive = fig_df[
    (fig_df["phase"] == "delay")
    & (fig_df["description"] == "Passive")
]
print(
    "dropped",
    sorted(DROP_CHANNELS),
    "| remaining sensory Passive response electrodes:",
    fig_df.loc[
        (fig_df.functional_cluster == "sensory")
        & (fig_df.phase == "response")
        & (fig_df.description == "Passive")
        & (fig_df.task == "PictureNaming"),
        "channel",
    ].nunique(),
)
print(
    "delay Passive tasks:",
    sorted(delay_passive.task.unique()) if len(delay_passive) else [],
    "| subjects:",
    delay_passive.subject.nunique() if len(delay_passive) else 0,
    "| electrodes:",
    delay_passive.channel.nunique() if len(delay_passive) else 0,
)

fig, axes = plt.subplots(
    nrows=n_rows,
    ncols=n_cols,
    figsize=(2.2 * n_cols * cm + 1.0 * cm, 2.4 * n_rows * cm),
    sharey="row",
    squeeze=False,
)
plt.subplots_adjust(wspace=0.05, hspace=0.4, left=0.28)

for row, cluster in enumerate(CLUSTERS):
    cluster_df = fig_df[fig_df["functional_cluster"] == cluster]
    label = CLUSTER_LABELS.get(cluster, cluster)
    cluster_color = FUNCTION_COLORS[cluster]
    for col, phase in enumerate(phases):
        ax = axes[row, col]
        phase_df = cluster_df[cluster_df["phase"] == phase]
        if phase == "response":
            phase_df = phase_df[
                ~(
                    (phase_df["description"] == "Passive")
                    & (phase_df["task"] == "LexicalNoDelay")
                )
            ]
        # Sustain @ stimulus: Passive is LexicalNoDelay only (not PictureNaming).
        if cluster == "sustain" and phase == "stimulus":
            phase_df = phase_df[
                ~(
                    (phase_df["description"] == "Passive")
                    & (phase_df["task"] != "LexicalNoDelay")
                )
            ]
        # Delay: Repeat/Decision are LexicalDelay. Passive is PictureNaming
        # (LexicalDelay has no Passive; LexicalNoDelay has no delay).
        if phase == "delay":
            phase_df = phase_df[
                (
                    (phase_df["task"] == "LexicalDelay")
                    & (phase_df["description"].isin(["Repeat", "Decision"]))
                )
                | (
                    (phase_df["task"] == "PictureNaming")
                    & (phase_df["description"] == "Passive")
                )
            ]
        present = [d for d in descriptions if (phase_df["description"] == d).any()]
        if phase_df.empty or not present:
            ax.text(
                0.5,
                0.5,
                "n/a",
                ha="center",
                va="center",
                fontsize=fontsize,
                transform=ax.transAxes,
                color="0.6",
            )
        else:
            legend = row == 0 and col == n_cols - 1
            sns.lineplot(
                data=phase_df,
                x="time",
                y="value",
                hue="description",
                hue_order=present,
                ax=ax,
                palette=cluster_condition_palette(cluster_color, present),
                legend=legend,
                lw=1,
                errorbar=("ci", 95),
            )
            if legend and ax.get_legend() is not None:
                ax.legend(title="", fontsize=fontsize, frameon=False)
            elif ax.get_legend() is not None:
                ax.get_legend().remove()

        ax.axvline(x=0, color="k", linestyle="--", linewidth=0.5)
        ax.axhline(y=0, color="k", linestyle="--", linewidth=0.5)
        ax.tick_params(labelsize=fontsize, width=0.75, length=2, which="both")
        plt.setp(ax.spines.values(), linewidth=0.75)
        sns.despine(ax=ax, offset=0.5, trim=True)
        ax.set_ylim(*ylim)
        if col != 0:
            ax.set_yticklabels([])
            ax.set_yticks([])
            ax.spines["left"].set_visible(False)
        ax.set_xlabel(
            f"{phase.capitalize()} (s)" if row == n_rows - 1 else "",
            fontsize=fontsize,
        )
        ax.set_ylabel(label if col == 0 else "", fontsize=fontsize)

fig.supylabel("HGA (z)", fontsize=fontsize, x=0.02)
fig.suptitle(
    f"n={fig_df.subject.nunique()} subjects",
    fontsize=fontsize,
    y=1.02,
)
out = save_svg(fig, IMG_DIR / "fig3_context_pooled_stim_resp")
print("Wrote", out)
plt.show()
# Out:
# response Passive tasks: ['PictureNaming'] | subjects: 27
# dropped ['D0125_LTMS1-2', 'D0125_LTMS2-3', 'D0125_LTMS3-4', 'D0129_LFAI2-3'] | remaining sensory Passive response electrodes: 13
# delay Passive tasks: ['PictureNaming'] | subjects: 27 | electrodes: 109
# Wrote /hpc/group/coganlab/nanlinshi/insula-functional/img/fig3/fig3_context_pooled_stim_resp.svg

# %% [markdown]
# ## Spotlight (old AIC claim, remapped)
#
# Mapped from `notebooks/modulation.ipynb` spotlights onto current names:
# sensory @ stimulus, motor @ response, sustain @ response.
# Pooled across the two tasks so Passive can show up on the NoDelay subjects.

# %%
SPOTLIGHTS = [
    {"cluster": "sensory", "phases": ["stimulus"], "title": "sensory"},
    {"cluster": "motor", "phases": ["response"], "title": "motor"},
    {"cluster": "sustain", "phases": ["response"], "title": "sustained"},
]

if plot_df.empty:
    print("Nothing to plot.")
else:
    plot_spotlight_waveforms(
        plot_df,
        SPOTLIGHTS,
        save_name="fig3_context_spotlights",
        title=f"Spotlights | n={plot_df.subject.nunique()} subjects",
    )
# Out:
# Wrote /hpc/group/coganlab/nanlinshi/insula-functional/img/fig3/fig3_context_spotlights.svg

# %% [markdown]
# ## 2. Spatial: Decision > Repeat
#
# LexicalDelay `DecisionVsRepeatMean`, **Decision larger**, **Delay phase only**
# (after delay onset, before Go).
# Data from `src/univariate/viz_cluster_direction.py`; render copied from
# `vizpub/fig2.ipynb` (insula mesh, fixed sphere size, KDE contours).
#
# Run on a compute node with GL. Marker size is fixed — not scaled by `|mean_diff|`.

# %%
from src.univariate.viz_cluster_direction import load_decision_vs_repeat_table

table, root = load_decision_vs_repeat_table(k=3)
print(f"results_root={root}")
print("phases in table:", sorted(table.phase.str.lower().unique()) if len(table) else [])

# Delay window only: after delay onset, before Go.
united = table.loc[
    (table["direction"] == "Decision")
    & (table["phase"].str.lower() == "delay")
].copy()
if "subject" in united.columns:
    united = united.loc[~united["subject"].isin(EXCLUDE_SUBJECTS)].copy()
if "channel" in united.columns:
    united = united.drop_duplicates(subset=["channel"], keep="first")
print(
    f"Delay Decision>Repeat channels: "
    f"{united.channel.nunique() if len(united) else 0}"
)
if len(united):
    print(
        united.groupby("functional_cluster")["channel"]
        .nunique()
        .reindex(CLUSTERS)
        .fillna(0)
        .astype(int)
        .to_string()
    )
# Out:
# results_root=/hpc/group/coganlab/nanlinshi/insula/results
# phases in table: ['delay', 'go', 'response', 'stimulus']
# Delay Decision>Repeat channels: 22
# functional_cluster
# sensory     3
# sustain    16
# motor       3

# %%
import os
import warnings

import pyvista as pv
from matplotlib.lines import Line2D
from matplotlib.path import Path as MplPath
from mne.viz import Brain
from scipy.ndimage import gaussian_filter
from scipy.spatial import cKDTree

os.environ.setdefault("PYVISTA_OFF_SCREEN", "true")
pv.OFF_SCREEN = True
mne.viz.set_3d_backend("notebook")

recon_dir = "/cwork/ns458/ECoG_Recon/"
template = "cvs_avg35_inMNI152"
insula_patterns = (
    "G_insular_short",
    "G_Ins_lg_and_S_cent_ins",
    "S_circular_insula_ant",
    "S_circular_insula_inf",
    "S_circular_insula_sup",
)
POINT_SIZE = 10.0
KDE_BANDWIDTH_PX = 25.0
KDE_LEVEL_FRAC = 0.18
KDE_FILL_ALPHA = 0.12
KDE_MIN_POINTS = 2
CROP_PAD_PX = 24
INSULA_COLOR = (0.9, 0.9, 0.9)
INSULA_LABEL_ALPHA = 0.55

labels = mne.read_labels_from_annot(
    subject=template,
    parc="aparc.a2009s",
    surf_name="pial",
    hemi="both",
    subjects_dir=recon_dir,
)
lh_pial_coords, lh_faces = mne.read_surface(f"{recon_dir}/{template}/surf/lh.pial")
rh_pial_coords, rh_faces = mne.read_surface(f"{recon_dir}/{template}/surf/rh.pial")
lh_tree = cKDTree(lh_pial_coords)
rh_tree = cKDTree(rh_pial_coords)


def _insula_vertices(hemi: str) -> np.ndarray:
    verts = []
    for lab in labels:
        if lab.hemi == hemi and any(p in lab.name for p in insula_patterns):
            verts.extend(lab.vertices)
    if not verts:
        raise RuntimeError(f"No insula labels for {hemi}")
    return np.unique(verts)


def _faces_to_polydata(coords, faces) -> pv.PolyData:
    faces_pv = np.hstack(
        [np.full((len(faces), 1), 3, dtype=np.int64), np.asarray(faces, dtype=np.int64)]
    ).ravel()
    return pv.PolyData(np.asarray(coords, dtype=float), faces_pv)


def insula_mesh(hemi: str, pial: np.ndarray, faces: np.ndarray):
    verts = _insula_vertices(hemi)
    keep = np.all(np.isin(faces, verts), axis=1)
    mesh = _faces_to_polydata(pial, faces[keep])
    center = pial[verts].mean(axis=0)
    return mesh, center


lh_insula, lh_insula_center = insula_mesh("lh", lh_pial_coords, lh_faces)
rh_insula, rh_insula_center = insula_mesh("rh", rh_pial_coords, rh_faces)


def snap_to_pial(coords, tree, pial):
    _, idx = tree.query(coords)
    return pial[idx]


def add_cluster_spheres(brain, coords, clusters, tree, pial):
    coords = np.asarray(coords, dtype=float)
    if coords.size == 0:
        return np.zeros((0, 3), dtype=float)
    snapped = snap_to_pial(coords, tree, pial)
    for cluster in CLUSTERS:
        mask = np.asarray(clusters) == cluster
        if not mask.any():
            continue
        cloud = pv.PolyData(np.asarray(snapped[mask], dtype=float))
        brain._renderer.plotter.add_mesh(
            cloud,
            render_points_as_spheres=True,
            point_size=POINT_SIZE,
            color=FUNCTION_COLORS[cluster],
            lighting=False,
        )
    return snapped


def project_xy(plotter, points, image_shape):
    pts = np.asarray(points, dtype=float)
    if pts.size == 0:
        return np.zeros((0, 2), dtype=float)
    if hasattr(plotter, "project_points_to_pixels"):
        pix = np.asarray(plotter.project_points_to_pixels(pts), dtype=float)
        xy = np.asarray(pix[:, :2], dtype=float)
    else:
        import vtk

        renderer = plotter.renderer
        coordinate = vtk.vtkCoordinate()
        coordinate.SetCoordinateSystemToWorld()
        xy = np.zeros((len(pts), 2), dtype=float)
        for i, (x, y, z) in enumerate(pts):
            coordinate.SetValue(float(x), float(y), float(z))
            d = coordinate.GetComputedDisplayValue(renderer)
            xy[i] = (float(d[0]), float(d[1]))
    h = int(image_shape[0])
    xy[:, 1] = (h - 1) - xy[:, 1]
    return xy


def _keep_ring(ring, pts) -> bool:
    if len(pts) < KDE_MIN_POINTS:
        return False
    return int(MplPath(np.asarray(ring, dtype=float)).contains_points(pts).sum()) >= KDE_MIN_POINTS


def kde_contour_rings(xy, image_shape, *, bandwidth_px=KDE_BANDWIDTH_PX, level_frac=KDE_LEVEL_FRAC):
    pts = np.asarray(xy, dtype=float)
    if len(pts) < 3:
        return []
    h, w = int(image_shape[0]), int(image_shape[1])
    dens = np.zeros((h, w), dtype=float)
    xs = np.clip(np.round(pts[:, 0]).astype(int), 0, w - 1)
    ys = np.clip(np.round(pts[:, 1]).astype(int), 0, h - 1)
    for x, y in zip(xs, ys):
        dens[y, x] += 1.0
    dens = gaussian_filter(dens, sigma=float(bandwidth_px))
    peak = float(dens.max())
    if peak <= 0:
        return []
    level = peak * float(level_frac)
    try:
        from skimage.measure import find_contours

        contours = find_contours(dens, level=level)
        rings = []
        for cont in contours:
            if len(cont) < 8:
                continue
            ring = np.column_stack([cont[:, 1], cont[:, 0]])
            ring = np.vstack([ring, ring[0]])
            if _keep_ring(ring, pts):
                rings.append(ring)
        return rings
    except ImportError:
        fig_c, ax_c = plt.subplots()
        yy, xx = np.mgrid[0:h, 0:w]
        cs = ax_c.contour(xx, yy, dens, levels=[level])
        rings = []
        for segs in cs.allsegs:
            for seg in segs:
                if len(seg) < 8:
                    continue
                ring = np.vstack([seg, seg[0]])
                if _keep_ring(ring, pts):
                    rings.append(ring)
        plt.close(fig_c)
        return rings


def draw_rings(ax, rings, color):
    for ring in rings:
        ax.fill(ring[:, 0], ring[:, 1], color=color, alpha=KDE_FILL_ALPHA, linewidth=0, zorder=3)
        ax.plot(
            ring[:, 0],
            ring[:, 1],
            color=color,
            linewidth=0.9,
            solid_capstyle="round",
            solid_joinstyle="round",
            zorder=4,
        )


def draw_ap_dv(ax, *, anterior_is_left: bool, corner: str):
    if corner == "lower left":
        x0, y0, arm = 0.16, 0.18, 0.08
    else:
        x0, y0, arm = 0.91, 0.16, 0.07
    gap = 0.012
    if anterior_is_left:
        tips = {"A": (x0 - arm, y0), "P": (x0 + arm, y0), "D": (x0, y0 + arm), "V": (x0, y0 - arm)}
    else:
        tips = {"A": (x0 + arm, y0), "P": (x0 - arm, y0), "D": (x0, y0 + arm), "V": (x0, y0 - arm)}
    for label, (tx, ty) in tips.items():
        sx = x0 + gap * np.sign(tx - x0) if tx != x0 else x0
        sy = y0 + gap * np.sign(ty - y0) if ty != y0 else y0
        ax.annotate(
            "",
            xy=(tx, ty),
            xytext=(sx, sy),
            xycoords="axes fraction",
            textcoords="axes fraction",
            arrowprops=dict(arrowstyle="->", color="0.25", lw=0.7, mutation_scale=7),
            annotation_clip=False,
        )
        px = 0.03 * np.sign(tx - x0) if tx != x0 else 0.0
        py = 0.035 * np.sign(ty - y0) if ty != y0 else 0.0
        ax.text(
            tx + px,
            ty + py,
            label,
            transform=ax.transAxes,
            ha="center",
            va="center",
            fontsize=fontsize,
            color="0.25",
            clip_on=False,
        )


def crop_to_content(img, xy, pad=CROP_PAD_PX):
    rgb = np.asarray(img)
    mask = np.any(rgb < 250, axis=2)
    if not mask.any():
        return rgb, np.asarray(xy, dtype=float)
    ys, xs = np.nonzero(mask)
    y0 = max(0, int(ys.min()) - pad)
    y1 = min(rgb.shape[0], int(ys.max()) + 1 + pad)
    x0 = max(0, int(xs.min()) - pad)
    x1 = min(rgb.shape[1], int(xs.max()) + 1 + pad)
    xy_c = np.asarray(xy, dtype=float).copy()
    if xy_c.size:
        xy_c[:, 0] -= x0
        xy_c[:, 1] -= y0
    return rgb[y0:y1, x0:x1], xy_c


def render_hemi(hemi: str, coords, clusters):
    brain = Brain(
        template,
        subjects_dir=recon_dir,
        surf="pial",
        hemi=hemi,
        background="white",
        show=False,
        cortex=INSULA_COLOR,
        alpha=0.0,
        size=(800, 800),
    )
    plotter = brain._renderer.plotter
    mesh = lh_insula if hemi == "lh" else rh_insula
    plotter.add_mesh(
        mesh,
        color=INSULA_COLOR,
        opacity=INSULA_LABEL_ALPHA,
        lighting=True,
        smooth_shading=True,
    )
    tree = lh_tree if hemi == "lh" else rh_tree
    pial = lh_pial_coords if hemi == "lh" else rh_pial_coords
    snapped = add_cluster_spheres(brain, coords, clusters, tree, pial)
    center = lh_insula_center if hemi == "lh" else rh_insula_center
    az = 180 if hemi == "lh" else 0
    brain.show_view(azimuth=az, elevation=90, distance=180, focalpoint=center)
    for _ in range(3):
        plotter.render()
    img = np.asarray(brain.screenshot(mode="rgb"))
    xy = project_xy(plotter, snapped, img.shape[:2])
    brain.close()
    return img, xy


need = {"x", "y", "z", "functional_cluster", "channel"}
# Re-slice here so this cell does not reuse a leftover phase-union `united`.
united = table.loc[
    (table["direction"] == "Decision")
    & (table["phase"].str.lower() == "delay")
].copy()
if "subject" in united.columns:
    united = united.loc[~united["subject"].isin(EXCLUDE_SUBJECTS)].copy()
if "channel" in united.columns:
    united = united.drop_duplicates(subset=["channel"], keep="first")
print(
    "plotting Delay Decision>Repeat channels:",
    united.channel.nunique() if len(united) else 0,
    "| phases:",
    sorted(united.phase.str.lower().unique()) if len(united) else [],
)
missing = need - set(united.columns)
if missing:
    raise ValueError(f"Delay Decision table missing {sorted(missing)}")

spatial = united.loc[
    united["functional_cluster"].isin(CLUSTERS)
    & united[["x", "y", "z"]].notna().all(axis=1)
].copy()
cord = spatial[["x", "y", "z"]].to_numpy(float)
clust = spatial["functional_cluster"].to_numpy()
mask_lh = cord[:, 0] < 0
mask_rh = cord[:, 0] > 0

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    lh_img, lh_xy = render_hemi("lh", cord[mask_lh], clust[mask_lh])
    rh_img, rh_xy = render_hemi("rh", cord[mask_rh], clust[mask_rh])

lh_img, lh_xy = crop_to_content(lh_img, lh_xy)
rh_img, rh_xy = crop_to_content(rh_img, rh_xy)
bw_px = KDE_BANDWIDTH_PX

fig, axes = plt.subplots(1, 2, figsize=(6.5 * cm, 3.0 * cm))
for ax, img, xy, clusters_hemi, title in (
    (axes[0], lh_img, lh_xy, clust[mask_lh], "Left"),
    (axes[1], rh_img, rh_xy, clust[mask_rh], "Right"),
):
    ax.imshow(img)
    ax.set_xlim(0, img.shape[1])
    ax.set_ylim(img.shape[0], 0)
    ax.axis("off")
    ax.set_title(title, fontsize=fontsize)
    in_frame = (
        (xy[:, 0] >= 0)
        & (xy[:, 0] < img.shape[1])
        & (xy[:, 1] >= 0)
        & (xy[:, 1] < img.shape[0])
    )
    for cluster in CLUSTERS:
        if cluster == "motor":
            continue
        pts = xy[in_frame & (np.asarray(clusters_hemi) == cluster)]
        draw_rings(
            ax,
            kde_contour_rings(pts, img.shape[:2], bandwidth_px=bw_px),
            FUNCTION_COLORS[cluster],
        )
    if title == "Left":
        draw_ap_dv(ax, anterior_is_left=True, corner="lower left")
    else:
        draw_ap_dv(ax, anterior_is_left=False, corner="lower right")

n_by_cluster = spatial.groupby("functional_cluster")["channel"].nunique()
axes[0].legend(
    handles=[
        Line2D(
            [0],
            [0],
            color=FUNCTION_COLORS[c],
            linewidth=0.9,
            label=f"{CLUSTER_LABELS[c]}  (n={int(n_by_cluster.get(c, 0))})",
        )
        for c in CLUSTERS
    ],
    frameon=False,
    fontsize=fontsize,
    loc="upper right",
    bbox_to_anchor=(-0.04, 1.0),
    borderaxespad=0.0,
)
fig.subplots_adjust(wspace=0.02, left=0.28, right=0.98, top=0.92, bottom=0.02)
out = save_svg(fig, IMG_DIR / "fig3_decision_gt_repeat_spatial_delay")
plt.show()
print("Wrote", out)
print(n_by_cluster.reindex(CLUSTERS).to_string())
# Out:
# Using notebook 3d backend.
# Reading labels from parcellation...
#    read 75 labels from /cwork/ns458/ECoG_Recon/cvs_avg35_inMNI152/label/lh.aparc.a2009s.annot
#    read 75 labels from /cwork/ns458/ECoG_Recon/cvs_avg35_inMNI152/label/rh.aparc.a2009s.annot
# plotting Delay Decision>Repeat channels: 22 | phases: ['delay']
# 2026-09-09 10:36:46.901 ( 387.276s) [    7F4E59552740]vtkXOpenGLRenderWindow.:1416  WARN| bad X server connection. DISPLAY=
# Wrote /hpc/group/coganlab/nanlinshi/insula-functional/img/fig3/fig3_decision_gt_repeat_spatial_delay.svg
# functional_cluster
# sensory     3
# sustain    16
# motor       3

# %% [markdown]
# ## 3. Paired Repeat vs Decision (Delay)
#
# LexicalDelay `DecisionVsRepeatP75`, Delay window only. Per-trial 75th percentile, not the mean.
# Each line is one NMF-assigned AIC/PIC electrode: Repeat (`mean_b`) vs Decision (`mean_a`).
# One panel per functional cluster. FDR-significant dots use cluster color; non-significant dots are gray.

# %%
from scipy.stats import gaussian_kde, wilcoxon

from src.paths import RESULTS_ROOT
from src.univariate.viz_cluster_direction import load_nmf_assignments
from src.univariate.viz_mean import (
    FALLBACK_MEAN_RESULTS,
    attach_metadata,
    filter_insula_electrodes,
    filter_qc,
    load_coord_metadata,
    load_mean_contrasts,
)

CONTRAST = "DecisionVsRepeatP75"
NS_COLOR = "0.62"
LINE_COLOR = "0.82"
X_REP, X_DEC = 0.0, 1.0
VIOLIN_W = 0.22
CLUSTER_DISPLAY = ["sensory", "sustain", "motor"]

mean_df = load_mean_contrasts(
    RESULTS_ROOT,
    tasks=("LexicalDelay",),
    phase="Delay",
    contrast_desc=CONTRAST,
)
coords = load_coord_metadata(FALLBACK_MEAN_RESULTS, tasks=("LexicalDelay",))
paired = attach_metadata(mean_df, coords)
paired = filter_qc(paired)
paired = filter_insula_electrodes(paired)
paired = paired.loc[
    (paired["contrast"] == CONTRAST)
    & (paired["phase"].str.lower() == "delay")
].copy()
if "subject" in paired.columns:
    paired = paired.loc[~paired["subject"].isin(EXCLUDE_SUBJECTS)].copy()
assign = load_nmf_assignments(k=3)
paired = paired.merge(
    assign[["channel", "functional_cluster"]],
    on="channel",
    how="inner",
)
paired = paired.drop_duplicates(subset=["channel"], keep="first")
paired = paired.loc[paired[["mean_a", "mean_b"]].notna().all(axis=1)].copy()
paired["significant"] = paired["significant"].astype(bool)
# Color only FDR-significant Decision > Repeat (mean_a = Decision, mean_b = Repeat).
paired["sig_up"] = paired["significant"] & (paired["mean_a"] > paired["mean_b"])
paired = paired.loc[paired["functional_cluster"].isin(CLUSTER_DISPLAY)].copy()

n_sig = int(paired["sig_up"].sum())
print(
    f"Delay paired electrodes: {len(paired)} "
    f"(Decision>Repeat sig={n_sig}, other={len(paired) - n_sig})"
)
print(
    paired.loc[paired["sig_up"]]
    .groupby("functional_cluster")["channel"]
    .nunique()
    .reindex(CLUSTER_DISPLAY)
    .fillna(0)
    .astype(int)
    .to_string()
)


def _half_violin(ax, values, x, *, side, color):
    v = np.asarray(values, float)
    v = v[np.isfinite(v)]
    if len(v) < 3:
        return
    y = np.linspace(np.percentile(v, 2), np.percentile(v, 98), 200)
    dens = gaussian_kde(v)(y)
    dens = dens / dens.max() * VIOLIN_W
    xs = x - dens if side == "left" else x + dens
    ax.fill_betweenx(y, np.full_like(xs, x), xs, color=color, alpha=0.18, lw=0, zorder=0)
    ax.plot(xs, y, color=color, lw=0.7, zorder=1)


stat, p_wil = wilcoxon(
    paired["mean_a"].to_numpy(float),
    paired["mean_b"].to_numpy(float),
    alternative="greater",
    zero_method="wilcox",
)

ymin = float(np.nanmin(np.r_[paired["mean_a"], paired["mean_b"]]))
ymax = float(np.nanmax(np.r_[paired["mean_a"], paired["mean_b"]]))
span = ymax - ymin if ymax > ymin else 1.0
ylim = (ymin - 0.08 * span, ymax + 0.28 * span)
ybar = ymax + 0.12 * span

fig, axes = plt.subplots(1, 3, figsize=(9 * cm, 4 * cm), sharey=True)
cluster_stats = []
for ax, cluster in zip(axes, CLUSTER_DISPLAY):
    sub = paired.loc[paired["functional_cluster"] == cluster].copy()
    color = FUNCTION_COLORS[cluster]
    _half_violin(ax, sub["mean_b"], X_REP, side="left", color=color)
    _half_violin(ax, sub["mean_a"], X_DEC, side="right", color=color)

    ns = sub.loc[~sub["sig_up"]]
    sig = sub.loc[sub["sig_up"]]
    for _, row in ns.iterrows():
        ax.plot(
            [X_REP, X_DEC],
            [row["mean_b"], row["mean_a"]],
            color=LINE_COLOR,
            lw=0.45,
            zorder=1,
            solid_capstyle="round",
        )
    for _, row in sig.iterrows():
        ax.plot(
            [X_REP, X_DEC],
            [row["mean_b"], row["mean_a"]],
            color=color,
            lw=0.7,
            zorder=2,
            solid_capstyle="round",
        )

    if len(ns):
        ax.scatter(
            np.full(len(ns), X_REP),
            ns["mean_b"],
            s=10,
            c=NS_COLOR,
            zorder=3,
            linewidths=0,
            clip_on=False,
        )
        ax.scatter(
            np.full(len(ns), X_DEC),
            ns["mean_a"],
            s=10,
            c=NS_COLOR,
            zorder=3,
            linewidths=0,
            clip_on=False,
        )
    if len(sig):
        ax.scatter(
            np.full(len(sig), X_REP),
            sig["mean_b"],
            s=14,
            c=color,
            zorder=4,
            linewidths=0,
            clip_on=False,
        )
        ax.scatter(
            np.full(len(sig), X_DEC),
            sig["mean_a"],
            s=14,
            c=color,
            zorder=4,
            linewidths=0,
            clip_on=False,
        )

    if len(sub) >= 8:
        _, p_c = wilcoxon(
            sub["mean_a"].to_numpy(float),
            sub["mean_b"].to_numpy(float),
            alternative="greater",
            zero_method="wilcox",
        )
        p_txt = f"$p = {p_c:.3g}$"
    else:
        p_c = np.nan
        p_txt = "n < 8"
    cluster_stats.append((cluster, len(sub), int(sub["sig_up"].sum()), p_c))

    ax.plot([X_REP, X_DEC], [ybar, ybar], color="0.2", lw=0.7, clip_on=False)
    ax.plot(
        [X_REP, X_REP], [ybar - 0.03 * span, ybar], color="0.2", lw=0.7, clip_on=False
    )
    ax.plot(
        [X_DEC, X_DEC], [ybar - 0.03 * span, ybar], color="0.2", lw=0.7, clip_on=False
    )
    ax.text(
        0.5,
        ybar + 0.02 * span,
        p_txt,
        ha="center",
        va="bottom",
        fontsize=fontsize,
        color="0.2",
        clip_on=False,
    )
    ax.set_xlim(-0.55, 1.55)
    ax.set_ylim(*ylim)
    ax.set_xticks([X_REP, X_DEC], ["Repeat", "Decision"])
    ax.set_title(
        f"{CLUSTER_LABELS[cluster]}  ({int(sub['sig_up'].sum())}/{len(sub)})",
        fontsize=fontsize,
    )
    ax.tick_params(labelsize=fontsize, width=0.75, length=2, which="both")
    plt.setp(ax.spines.values(), linewidth=0.75)
    sns.despine(ax=ax, offset=1, trim=True)

axes[0].set_ylabel("P75 HGA\nduring Delay (z)", fontsize=fontsize)
handles = [
    plt.Line2D(
        [0],
        [0],
        marker="o",
        color="none",
        markerfacecolor=FUNCTION_COLORS[c],
        markersize=4,
        label=CLUSTER_LABELS[c],
    )
    for c in CLUSTER_DISPLAY
] + [
    plt.Line2D(
        [0],
        [0],
        marker="o",
        color="none",
        markerfacecolor=NS_COLOR,
        markersize=4,
        label="n.s.",
    )
]
axes[-1].legend(
    handles=handles,
    frameon=False,
    fontsize=fontsize,
    loc="upper left",
    bbox_to_anchor=(1.02, 1.0),
)

out = save_svg(fig, IMG_DIR / "fig3_decision_gt_repeat_paired_delay_p75")
plt.show()
print("Wrote", out)
print(f"Wilcoxon Decision>Repeat (all): W={stat:.3g}, p={p_wil:.4g}, n={len(paired)}")
for cluster, n, n_sig_c, p_c in cluster_stats:
    p_str = f"{p_c:.4g}" if np.isfinite(p_c) else "NA"
    print(f"  {cluster}: n={n}, sig={n_sig_c}, p={p_str}")
# Out:
# Delay paired electrodes: 154 (Decision>Repeat sig=22, other=132)
# functional_cluster
# sensory     3
# sustain    16
# motor       3
# Wrote /hpc/group/coganlab/nanlinshi/insula-functional/img/fig3/fig3_decision_gt_repeat_paired_delay.svg
# Wilcoxon Decision>Repeat (all): W=7.4e+03, p=0.00496, n=154
#   sensory: n=21, sig=3, p=0.4864
#   sustain: n=52, sig=16, p=1.457e-05
#   motor: n=81, sig=3, p=0.6953

# %% [markdown]
# ## 4. Paired Repeat vs Passive (Delay)
#
# PictureNaming `RepeatVsPassiveP75`, Delay window only.
# Per-trial window summary is the 75th percentile (robust peak), not the mean.
# Each line is one NMF-assigned AIC/PIC electrode: Passive (`mean_b`) vs Repeat (`mean_a`).
# Color = uncorrected trial-level *p* < 0.05 and Repeat > Passive (no FDR). Gray = otherwise.

# %%
from scipy.stats import gaussian_kde, wilcoxon

from src.paths import RESULTS_ROOT
from src.univariate.viz_cluster_direction import load_nmf_assignments
from src.univariate.viz_mean import (
    FALLBACK_MEAN_RESULTS,
    attach_metadata,
    filter_insula_electrodes,
    filter_qc,
    load_coord_metadata,
    load_mean_contrasts,
)

CONTRAST = "RepeatVsPassiveP75"
RVP_TASKS = ("PictureNaming",)
NS_COLOR = "0.62"
LINE_COLOR = "0.82"
X_PAS, X_REP = 0.0, 1.0
VIOLIN_W = 0.22
CLUSTER_DISPLAY = ["sensory", "sustain", "motor"]

mean_df = load_mean_contrasts(
    RESULTS_ROOT,
    tasks=RVP_TASKS,
    phase="Delay",
    contrast_desc=CONTRAST,
)
coords = load_coord_metadata(FALLBACK_MEAN_RESULTS, tasks=RVP_TASKS)
paired = attach_metadata(mean_df, coords)
paired = filter_qc(paired)
paired = filter_insula_electrodes(paired)
paired = paired.loc[
    (paired["contrast"] == CONTRAST)
    & (paired["phase"].str.lower() == "delay")
].copy()
if "subject" in paired.columns:
    paired = paired.loc[~paired["subject"].isin(EXCLUDE_SUBJECTS)].copy()
assign = load_nmf_assignments(k=3)
paired = paired.merge(
    assign[["channel", "functional_cluster"]],
    on="channel",
    how="inner",
)
paired = paired.drop_duplicates(subset=["channel"], keep="first")
paired = paired.loc[paired[["mean_a", "mean_b"]].notna().all(axis=1)].copy()
paired["significant"] = paired["significant"].astype(bool)
# Color uncorrected p < 0.05 Repeat > Passive (no FDR; mean_a = Repeat, mean_b = Passive).
paired["sig_up"] = (paired["p_value"] < 0.05) & (paired["mean_a"] > paired["mean_b"])
paired = paired.loc[paired["functional_cluster"].isin(CLUSTER_DISPLAY)].copy()

n_sig = int(paired["sig_up"].sum())
print(
    f"Delay paired electrodes: {len(paired)} "
    f"(Repeat>Passive unc p<0.05={n_sig}, other={len(paired) - n_sig})"
)
print(
    paired.loc[paired["sig_up"]]
    .groupby("functional_cluster")["channel"]
    .nunique()
    .reindex(CLUSTER_DISPLAY)
    .fillna(0)
    .astype(int)
    .to_string()
)


def _half_violin(ax, values, x, *, side, color):
    v = np.asarray(values, float)
    v = v[np.isfinite(v)]
    if len(v) < 3:
        return
    y = np.linspace(np.percentile(v, 2), np.percentile(v, 98), 200)
    dens = gaussian_kde(v)(y)
    dens = dens / dens.max() * VIOLIN_W
    xs = x - dens if side == "left" else x + dens
    ax.fill_betweenx(y, np.full_like(xs, x), xs, color=color, alpha=0.18, lw=0, zorder=0)
    ax.plot(xs, y, color=color, lw=0.7, zorder=1)


stat, p_wil = wilcoxon(
    paired["mean_a"].to_numpy(float),
    paired["mean_b"].to_numpy(float),
    alternative="greater",
    zero_method="wilcox",
)

ymin = float(np.nanmin(np.r_[paired["mean_a"], paired["mean_b"]]))
ymax = float(np.nanmax(np.r_[paired["mean_a"], paired["mean_b"]]))
span = ymax - ymin if ymax > ymin else 1.0
ylim = (ymin - 0.08 * span, ymax + 0.28 * span)
ybar = ymax + 0.12 * span

fig, axes = plt.subplots(1, 3, figsize=(9 * cm, 4 * cm), sharey=True)
cluster_stats = []
for ax, cluster in zip(axes, CLUSTER_DISPLAY):
    sub = paired.loc[paired["functional_cluster"] == cluster].copy()
    color = FUNCTION_COLORS[cluster]
    _half_violin(ax, sub["mean_b"], X_PAS, side="left", color=color)
    _half_violin(ax, sub["mean_a"], X_REP, side="right", color=color)

    ns = sub.loc[~sub["sig_up"]]
    sig = sub.loc[sub["sig_up"]]
    for _, row in ns.iterrows():
        ax.plot(
            [X_PAS, X_REP],
            [row["mean_b"], row["mean_a"]],
            color=LINE_COLOR,
            lw=0.45,
            zorder=1,
            solid_capstyle="round",
        )
    for _, row in sig.iterrows():
        ax.plot(
            [X_PAS, X_REP],
            [row["mean_b"], row["mean_a"]],
            color=color,
            lw=0.7,
            zorder=2,
            solid_capstyle="round",
        )

    if len(ns):
        ax.scatter(
            np.full(len(ns), X_PAS),
            ns["mean_b"],
            s=10,
            c=NS_COLOR,
            zorder=3,
            linewidths=0,
            clip_on=False,
        )
        ax.scatter(
            np.full(len(ns), X_REP),
            ns["mean_a"],
            s=10,
            c=NS_COLOR,
            zorder=3,
            linewidths=0,
            clip_on=False,
        )
    if len(sig):
        ax.scatter(
            np.full(len(sig), X_PAS),
            sig["mean_b"],
            s=14,
            c=color,
            zorder=4,
            linewidths=0,
            clip_on=False,
        )
        ax.scatter(
            np.full(len(sig), X_REP),
            sig["mean_a"],
            s=14,
            c=color,
            zorder=4,
            linewidths=0,
            clip_on=False,
        )

    if len(sub) >= 8:
        _, p_c = wilcoxon(
            sub["mean_a"].to_numpy(float),
            sub["mean_b"].to_numpy(float),
            alternative="greater",
            zero_method="wilcox",
        )
        p_txt = f"$p = {p_c:.3g}$"
    else:
        p_c = np.nan
        p_txt = "n < 8"
    cluster_stats.append((cluster, len(sub), int(sub["sig_up"].sum()), p_c))

    ax.plot([X_PAS, X_REP], [ybar, ybar], color="0.2", lw=0.7, clip_on=False)
    ax.plot(
        [X_PAS, X_PAS], [ybar - 0.03 * span, ybar], color="0.2", lw=0.7, clip_on=False
    )
    ax.plot(
        [X_REP, X_REP], [ybar - 0.03 * span, ybar], color="0.2", lw=0.7, clip_on=False
    )
    ax.text(
        0.5,
        ybar + 0.02 * span,
        p_txt,
        ha="center",
        va="bottom",
        fontsize=fontsize,
        color="0.2",
        clip_on=False,
    )
    ax.set_xlim(-0.55, 1.55)
    ax.set_ylim(*ylim)
    ax.set_xticks([X_PAS, X_REP], ["Passive", "Repeat"])
    ax.set_title(
        f"{CLUSTER_LABELS[cluster]}  ({int(sub['sig_up'].sum())}/{len(sub)})",
        fontsize=fontsize,
    )
    ax.tick_params(labelsize=fontsize, width=0.75, length=2, which="both")
    plt.setp(ax.spines.values(), linewidth=0.75)
    sns.despine(ax=ax, offset=1, trim=True)

axes[0].set_ylabel("P75 HGA\nduring Delay (z)", fontsize=fontsize)
handles = [
    plt.Line2D(
        [0],
        [0],
        marker="o",
        color="none",
        markerfacecolor=FUNCTION_COLORS[c],
        markersize=4,
        label=CLUSTER_LABELS[c],
    )
    for c in CLUSTER_DISPLAY
] + [
    plt.Line2D(
        [0],
        [0],
        marker="o",
        color="none",
        markerfacecolor=NS_COLOR,
        markersize=4,
        label="p ≥ 0.05",
    )
]
axes[-1].legend(
    handles=handles,
    frameon=False,
    fontsize=fontsize,
    loc="upper left",
    bbox_to_anchor=(1.02, 1.0),
)

out = save_svg(fig, IMG_DIR / "fig3_repeat_gt_passive_paired_delay_p75")
plt.show()
print("Wrote", out)
print(f"Wilcoxon Repeat>Passive (all): W={stat:.3g}, p={p_wil:.4g}, n={len(paired)}")
for cluster, n, n_sig_c, p_c in cluster_stats:
    p_str = f"{p_c:.4g}" if np.isfinite(p_c) else "NA"
    print(f"  {cluster}: n={n}, sig={n_sig_c}, p={p_str}")
# Out:
# Delay paired electrodes: 116 (Repeat>Passive unc p<0.05=12, other=104)
# functional_cluster
# sensory    1
# sustain    8
# motor      3
# Wrote /hpc/group/coganlab/nanlinshi/insula-functional/img/fig3/fig3_repeat_gt_passive_paired_delay.svg
# Wilcoxon Repeat>Passive (all): W=3.95e+03, p=0.06382, n=116
#   sensory: n=15, sig=1, p=0.6401
#   sustain: n=46, sig=8, p=0.0006263
#   motor: n=55, sig=3, p=0.746

# %% [markdown]
# Same paired Delay data, one axis: cluster half-violins overlaid (not faceted).
# Significant dots keep cluster color; non-significant dots are gray.
