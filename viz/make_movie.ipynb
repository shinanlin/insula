# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
from pathlib import Path
from IPython.display import Audio
import IPython.display as ipd
from scipy.io import wavfile
import tempfile
import os
import librosa
import pandas as pd
import seaborn as sns
import h5py
import mne
from scipy.stats import zscore
from mne_bids import BIDSPath, read_raw_bids
from matplotlib_venn import venn2,venn2_circles
from tqdm import tqdm

# %%
cm = 1/2.54
plt.rcParams['svg.fonttype'] = 'none'

fontdict = dict(fontsize=7)
fontsize = 7

red = '#A9373B'
blue = '#2369BD'
orange = '#CC8963'
green = '#009944'

stg_color = '#20B2AA'
smc_color = '#6A5ACD'
insula_color = '#D4AF37'

reds = sns.light_palette(red, as_cmap=True)
blues = sns.light_palette(blue, as_cmap=True)
oranges = sns.light_palette(orange, as_cmap=True)
greens = sns.light_palette(green, as_cmap=True)

recon_dir = '/cwork/ns458/ECoG_Recon/'
mne.viz.set_3d_backend('notebook')                    # MNE 3D in-notebook static backend
# text svg
# Out:
# Using notebook 3d backend.

# %% [markdown]
# # Production

# %%
import pandas as pd
import numpy as np
from mne_bids import BIDSPath
from tqdm import tqdm

# 1. 加载所有 time 数据
task = ['PhonemeSequence', 'SentenceRep', 'TIMIT', 'LexicalDelay']
ref = 'bipolar'

time_paths = []
for t in task:
    time_paths.extend(
        BIDSPath(
            root=f'../results/{t}({ref})',
            datatype='HGA',
            suffix='time',
            check=False,
        ).match()
    )

# 2. 加载数据
time_dfs = []
for path in tqdm(time_paths):
    df = pd.read_csv(path)
    time_dfs.append(df)

time_data = pd.concat(time_dfs)

# rename both phase : Resp and Response to Resp
time_data.loc[time_data.phase == 'Resp', 'phase'] = 'Response'
time_data.loc[time_data.phase == 'Response', 'phase'] = 'Response'

# rename phase of perception to audio
time_data.loc[time_data.description == 'passive', 'phase'] = 'Audio'
time_data.loc[time_data.description == 'perception', 'phase'] = 'Audio'
time_data.loc[time_data.description == 'production', 'phase'] = 'Response'

time_data = time_data[time_data.phase=='Response']

# rename ROIs
time_data.loc[time_data.roi == 'INS', 'roi'] = 'Insula'
time_data.loc[time_data.roi == 'HG', 'roi'] = 'STG'
time_data.loc[time_data.roi == 'PrG', 'roi'] = 'SMC'
time_data.loc[time_data.roi == 'PoG', 'roi'] = 'SMC'
time_data.loc[time_data.roi == 'Subcentral', 'roi'] = 'SMC'

# 只保留 time >= -0.5
speak_data = time_data[(time_data['time'] <= 1) & 
                        (time_data['time'] >= -1)]

print(f"筛选后数据量: {len(speak_data)}")
print(f"description 分布: {speak_data.description.unique()}")
print(f"phase 分布: {speak_data.phase.unique()}")
print(f"task 分布: {speak_data.task.unique()}")

# 4. groupby 计算 peak HGA
speak_hga = speak_data.groupby('channel').agg({
    'value': 'mean', 
    'label': 'first', 
    'x': 'first',
    'y': 'first', 
    'z': 'first',
    'roi': 'first',
    'hemi': 'first',
    'subject': 'first',
    'description': 'first',
    'phase':'first',
    'task':'first'
}).reset_index()

speak_hga.rename(columns={'value': 'HGA'}, inplace=True)
speak_hga['HGA'] = speak_hga['HGA'].astype(float)

speak_hga.head()
# Out:
# 100%|██████████| 975/975 [00:35<00:00, 27.59it/s]
# 筛选后数据量: 1855899
# description 分布: ['production' 'LS' 'Decision' 'Repeat']
# phase 分布: ['Response']
# task 分布: ['PhonemeSequence' 'SentenceRep' 'LexicalDelay']
#           channel       HGA                      label          x          y  \
# 0  D0005_LTG14-15  0.317243  ctx_lh_G_temp_sup-Lateral -68.886726 -28.295294
# 1  D0005_LTG15-16  0.231774  ctx_lh_G_temp_sup-Lateral -69.639740 -38.151283
# 2  D0005_LTG24-26 -0.049250      ctx_lh_G_temporal_inf -57.666666 -21.463809
# 3  D0005_LTG29-30  0.123241      ctx_lh_G_temporal_inf -54.534528 -29.265764
# 4  D0005_LTG30-31  0.166120      ctx_lh_G_temporal_inf -55.770381 -38.615740
#
#            z  roi hemi subject description     phase         task
# 0   0.243498  STG    L   D0005          LS  Response  SentenceRep
# 1   4.609248  STG    L   D0005          LS  Response  SentenceRep
# 2 -25.843526  ITG    L   D0005          LS  Response  SentenceRep
# 3 -28.078430  ITG    L   D0005          LS  Response  SentenceRep
# 4 -23.875112  ITG    L   D0005          LS  Response  SentenceRep

# %%
# 3D Insula HGA Video Generation
import numpy as np
import pyvista as pv
import matplotlib.pyplot as plt
from mne.viz import Brain
from scipy.spatial import cKDTree
import matplotlib.colors as mcolors
from tqdm import tqdm
import imageio.v2 as imageio
from io import BytesIO
from PIL import Image

# 读取aparc.a2009s labels
labels = mne.read_labels_from_annot(
    subject='fsaverage', parc='aparc.a2009s',  
    hemi='both', subjects_dir=recon_dir
)

# Insula相关的labels
insula_patterns = ['G_insular_short', 'G_Ins_lg_and_S_cent_ins', 
                   'S_circular_insula_ant', 'S_circular_insula_inf', 'S_circular_insula_sup']

# 加载pial表面用于投影
lh_pial_coords, _ = mne.read_surface(f"{recon_dir}/fsaverage/surf/lh.pial")
rh_pial_coords, _ = mne.read_surface(f"{recon_dir}/fsaverage/surf/rh.pial")
lh_tree = cKDTree(lh_pial_coords)
rh_tree = cKDTree(rh_pial_coords)

# 计算insula区域的中心点
def get_insula_center(labels, hemi, pial_coords):
    vertices = []
    for lab in labels:
        if lab.hemi == hemi and any(p in lab.name for p in insula_patterns):
            vertices.extend(lab.vertices)
    if vertices:
        return pial_coords[vertices].mean(axis=0)
    return None

lh_insula_center = get_insula_center(labels, 'lh', lh_pial_coords)
rh_insula_center = get_insula_center(labels, 'rh', rh_pial_coords)

# 筛选insula数据
insula_data = speak_data[speak_data['roi'] == 'Insula'].copy()
print(f"Insula electrodes: {insula_data['channel'].nunique()}")

# 参数设置
window_size = 0.1  # 100ms window
step_size = 0.05   # 50ms step
time_min, time_max = insula_data['time'].min(), insula_data['time'].max()
time_points = np.arange(time_min, time_max - window_size + step_size, step_size)

# 固定的vmin, vmax (across all windows)
all_values = insula_data['value'].values
vmin, vmax = 0, np.percentile(all_values[all_values > 0], 95)
print(f"Fixed colormap range: [{vmin:.3f}, {vmax:.3f}]")

# 点大小映射参数
size_min, size_max = 8, 25
cmap = reds

def hga_to_size(hga, vmin, vmax, size_min, size_max):
    normalized = np.clip((hga - vmin) / (vmax - vmin), 0, 1)
    return size_min + normalized * (size_max - size_min)

def generate_frame(t_start, insula_data, lh_tree, rh_tree, lh_pial_coords, rh_pial_coords,
                   labels, insula_patterns, lh_insula_center, rh_insula_center,
                   cmap, vmin, vmax, size_min, size_max, window_size, time_min, time_max):
    """生成单帧图像"""
    t_end = t_start + window_size
    
    # 计算当前窗口的HGA
    window_data = insula_data[(insula_data['time'] >= t_start) & (insula_data['time'] < t_end)]
    hga_df = window_data.groupby('channel').agg({
        'value': 'mean',
        'x': 'first', 'y': 'first', 'z': 'first'
    }).reset_index()
    
    if len(hga_df) == 0:
        return None
    
    cord = hga_df[['x', 'y', 'z']].values
    hga_values = hga_df['value'].values
    mask_lh = cord[:, 0] < 0
    mask_rh = cord[:, 0] > 0
    
    norm = mcolors.Normalize(vmin=vmin, vmax=vmax)
    
    # 创建Brain对象
    lh_brain = Brain("fsaverage", subjects_dir=recon_dir, surf="pial",
                     hemi="lh", background="white", show=False,
                     cortex=(0.9, 0.9, 0.9), alpha=0.05, size=(800, 800))
    rh_brain = Brain("fsaverage", subjects_dir=recon_dir, surf="pial",
                     hemi="rh", background="white", show=False,
                     cortex=(0.9, 0.9, 0.9), alpha=0.05, size=(800, 800))
    
    # 添加insula labels
    for lab in labels:
        if any(pattern in lab.name for pattern in insula_patterns):
            if lab.hemi == 'lh':
                lh_brain.add_label(lab, borders=False, color=(0.9, 0.9, 0.9), alpha=0.6)
            elif lab.hemi == 'rh':
                rh_brain.add_label(lab, borders=False, color=(0.9, 0.9, 0.9), alpha=0.6)
    
    # 添加电极
    def add_electrodes(brain, coords, hga_vals, tree, pial_coords):
        if len(coords) == 0:
            return
        _, indices = tree.query(coords)
        coords_proj = pial_coords[indices]
        for i in range(len(coords_proj)):
            pt = coords_proj[i:i+1]
            hga = hga_vals[i]
            color = cmap(norm(hga))[:3]
            size = hga_to_size(hga, vmin, vmax, size_min, size_max)
            cloud = pv.PolyData(pt)
            brain._renderer.plotter.add_mesh(cloud, render_points_as_spheres=True,
                                             point_size=size, color=color, lighting=False)
    
    if mask_lh.any():
        add_electrodes(lh_brain, cord[mask_lh], hga_values[mask_lh], lh_tree, lh_pial_coords)
    if mask_rh.any():
        add_electrodes(rh_brain, cord[mask_rh], hga_values[mask_rh], rh_tree, rh_pial_coords)
    
    # 设置视角
    lh_brain.show_view(azimuth=180, elevation=90, distance=180, focalpoint=lh_insula_center)
    rh_brain.show_view(azimuth=0, elevation=90, distance=180, focalpoint=rh_insula_center)
    
    # 创建图像
    fig, axes = plt.subplots(1, 2, figsize=(16*cm, 10*cm))
    
    axes[0].imshow(lh_brain.screenshot(mode="rgb"))
    axes[0].axis("off")
    axes[0].set_title("Left Insula", fontsize=fontsize)
    
    axes[1].imshow(rh_brain.screenshot(mode="rgb"))
    axes[1].axis("off")
    axes[1].set_title("Right Insula", fontsize=fontsize)
    
    lh_brain.close()
    rh_brain.close()
    
    # 添加colorbar
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])
    cbar = fig.colorbar(sm, ax=axes, orientation='horizontal', fraction=0.04, pad=0.02, aspect=30)
    cbar.set_label('HGA (z-score)', fontsize=fontsize)
    cbar.ax.tick_params(labelsize=fontsize)
    
    # 添加时间轴
    ax_time = fig.add_axes([0.15, 0.02, 0.7, 0.03])
    ax_time.set_xlim(time_min, time_max)
    ax_time.set_ylim(0, 1)
    ax_time.axvline(x=0, color='gray', linestyle='--', linewidth=0.5)
    
    # 当前时间窗口
    ax_time.axvspan(t_start, t_end, color=red, alpha=0.5)
    ax_time.plot((t_start + t_end) / 2, 0.5, 'ko', markersize=5)
    
    ax_time.set_xlabel('Time (s)', fontsize=fontsize)
    ax_time.set_yticks([])
    ax_time.tick_params(labelsize=fontsize)
    for spine in ['top', 'left', 'right']:
        ax_time.spines[spine].set_visible(False)
    
    plt.suptitle(f"Production HGA: {t_start:.2f}s - {t_end:.2f}s", fontsize=fontsize+1)
    
    # 转换为图像数组 (使用PIL方式)
    buf = BytesIO()
    fig.savefig(buf, format='png', dpi=100, bbox_inches='tight')
    buf.seek(0)
    img = np.array(Image.open(buf).convert('RGB'))
    buf.close()
    plt.close(fig)
    
    return img

# 生成所有帧
frames = []
for t in tqdm(time_points, desc="Generating frames"):
    img = generate_frame(t, insula_data, lh_tree, rh_tree, lh_pial_coords, rh_pial_coords,
                         labels, insula_patterns, lh_insula_center, rh_insula_center,
                         cmap, vmin, vmax, size_min, size_max, window_size, time_min, time_max)
    if img is not None:
        frames.append(img)

# 保存视频 (使用gif格式避免codec问题)
output_path = '../img/insula_hga_production.gif'
imageio.mimsave(output_path, frames, duration=100)  # 100ms per frame = 10fps
print(f"Video saved to {output_path}")
# Out:
# Reading labels from parcellation...
#    read 75 labels from /cwork/ns458/ECoG_Recon/fsaverage/label/lh.aparc.a2009s.annot
#    read 75 labels from /cwork/ns458/ECoG_Recon/fsaverage/label/rh.aparc.a2009s.annot
# Insula electrodes: 207
# Fixed colormap range: [0.000, 0.807]
# Generating frames:   0%|          | 0/39 [00:00<?, ?it/s]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:24.565 ( 207.955s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6b83d080): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:24.676 ( 208.067s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6b83d080): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:24.792 ( 208.183s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x53923fa0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:25.035 ( 208.426s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x72883560): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:25.132 ( 208.522s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x50384ca0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:26.228 ( 209.619s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x72883560): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:26.338 ( 209.728s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x72883560): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:26.435 ( 209.826s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7498de40): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:26.715 ( 210.106s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x72883560): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:26.822 ( 210.212s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x61f36010): EGL device index: 0 could not be initialized. Trying other devices...
# Generating frames:   3%|▎         | 1/39 [00:08<05:37,  8.89s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:33.462 ( 216.853s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7b4792c0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:33.591 ( 216.982s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7b44c0e0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:33.725 ( 217.116s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7b4792c0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:34.086 ( 217.477s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x600c7e10): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:34.212 ( 217.603s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7b44c0e0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:35.330 ( 218.721s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x79a91540): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:35.445 ( 218.835s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x600c7e10): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:35.560 ( 218.950s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5c272ca0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:35.821 ( 219.211s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x600c7e10): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:35.927 ( 219.318s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x79a91540): EGL device index: 0 could not be initialized. Trying other devices...
# Generating frames:   5%|▌         | 2/39 [00:18<05:44,  9.30s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:43.052 ( 226.443s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x77024e50): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:43.174 ( 226.565s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x77024e50): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:43.282 ( 226.673s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x600c7e10): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:43.575 ( 226.966s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5d0b8350): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:43.688 ( 227.079s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7b3f1b10): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:44.654 ( 228.045s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5d0b8350): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:44.757 ( 228.148s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5d0b8350): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:44.846 ( 228.237s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x64210b80): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:45.083 ( 228.473s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7705b890): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:45.170 ( 228.560s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x77024e50): EGL device index: 0 could not be initialized. Trying other devices...
# Generating frames:   8%|▊         | 3/39 [00:27<05:26,  9.06s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:51.846 ( 235.237s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5e7dc720): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:51.950 ( 235.341s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7705b890): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:52.054 ( 235.445s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5e7dc720): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:52.302 ( 235.692s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5362c120): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:52.403 ( 235.794s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7705b890): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:53.375 ( 236.765s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7686e240): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:53.467 ( 236.858s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7686e240): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:53.568 ( 236.959s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5362c120): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:53.852 ( 237.243s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x796d4ea0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:24:53.950 ( 237.341s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7686e240): EGL device index: 0 could not be initialized. Trying other devices...
# Generating frames:  10%|█         | 4/39 [00:35<05:06,  8.77s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:00.135 ( 243.526s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x738bfee0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:00.262 ( 243.652s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x796d4ea0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:00.369 ( 243.759s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x738bfee0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:00.638 ( 244.029s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6b175a70): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:00.758 ( 244.148s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x67533100): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:01.661 ( 245.052s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6b175a70): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:01.752 ( 245.142s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6b175a70): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:01.866 ( 245.256s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x796d4ea0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:02.114 ( 245.505s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x70de6020): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:02.213 ( 245.603s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6b175a70): EGL device index: 0 could not be initialized. Trying other devices...
# Generating frames:  13%|█▎        | 5/39 [00:43<04:42,  8.32s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:07.647 ( 251.037s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6aa17540): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:07.737 ( 251.128s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x70de6020): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:07.846 ( 251.237s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6aa17540): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:08.088 ( 251.479s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5bcc7a60): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:08.192 ( 251.582s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x70de6020): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:09.047 ( 252.438s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5bcc7a60): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:09.151 ( 252.542s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x72f44400): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:09.265 ( 252.656s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5bcc7a60): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:09.522 ( 252.913s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x60617550): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:09.623 ( 253.014s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7539a930): EGL device index: 0 could not be initialized. Trying other devices...
# Generating frames:  15%|█▌        | 6/39 [00:50<04:19,  7.88s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:14.662 ( 258.053s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x71843cf0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:14.748 ( 258.138s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x72f44400): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:14.849 ( 258.240s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x71843cf0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:15.082 ( 258.473s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x621839a0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:15.181 ( 258.572s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x72f44400): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:16.003 ( 259.394s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x768746e0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:16.085 ( 259.475s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x768746e0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:16.178 ( 259.569s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x621839a0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:16.422 ( 259.813s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7985e6c0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:16.524 ( 259.915s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x768746e0): EGL device index: 0 could not be initialized. Trying other devices...
# Generating frames:  18%|█▊        | 7/39 [00:57<04:04,  7.64s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:21.813 ( 265.204s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6e124eb0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:21.905 ( 265.296s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7985e6c0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:22.009 ( 265.400s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6e124eb0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:22.232 ( 265.623s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5d4f92b0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:22.324 ( 265.715s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7985e6c0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:23.277 ( 266.667s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x70de4a80): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:23.378 ( 266.769s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5d4f92b0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:23.474 ( 266.865s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x70de4a80): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:23.732 ( 267.122s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x67556f90): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:23.833 ( 267.224s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5d4f92b0): EGL device index: 0 could not be initialized. Trying other devices...
# Generating frames:  21%|██        | 8/39 [01:04<03:56,  7.63s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:29.411 ( 272.801s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7b129f60): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:29.547 ( 272.937s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x8219e350): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:29.665 ( 273.055s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7b129f60): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:29.917 ( 273.308s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7acebba0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:30.008 ( 273.398s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x819a6600): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:31.058 ( 274.449s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7acebba0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:31.152 ( 274.543s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x8219e350): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:31.257 ( 274.647s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x675effe0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:31.498 ( 274.889s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x8219e350): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:31.599 ( 274.990s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7acebba0): EGL device index: 0 could not be initialized. Trying other devices...
# Generating frames:  23%|██▎       | 9/39 [01:11<03:43,  7.45s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:36.488 ( 279.878s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6b71e370): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:36.606 ( 279.996s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x8219e350): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:36.734 ( 280.125s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6b71e370): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:37.171 ( 280.561s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5d043260): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:37.300 ( 280.691s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x823a2540): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:38.380 ( 281.770s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6bae2420): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:38.501 ( 281.892s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5d043260): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:38.607 ( 281.998s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6c489890): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:38.893 ( 282.283s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5d043260): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:39.007 ( 282.397s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6bae2420): EGL device index: 0 could not be initialized. Trying other devices...
# Generating frames:  26%|██▌       | 10/39 [01:21<03:51,  7.99s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:45.711 ( 289.102s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x70e91610): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:45.815 ( 289.206s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5d043260): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:45.913 ( 289.303s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x70e91610): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:46.165 ( 289.555s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7931d220): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:46.253 ( 289.643s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5d043260): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:47.054 ( 290.444s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x618bb0e0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:47.155 ( 290.546s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x618bb0e0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:47.264 ( 290.655s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7931d220): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:25:47.522 ( 290.913s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5287ef70): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# ...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:17.485 ( 500.876s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6acf2930): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:18.554 ( 501.945s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x61fda880): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:18.661 ( 502.052s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6ace6710): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:18.769 ( 502.159s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x61fda880): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:19.029 ( 502.420s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7cf53f60): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:19.134 ( 502.525s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x500cb480): EGL device index: 0 could not be initialized. Trying other devices...
# Generating frames:  92%|█████████▏| 36/39 [05:01<00:25,  8.64s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:25.943 ( 509.334s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x8111e180): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:26.042 ( 509.433s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x81984b60): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:26.149 ( 509.540s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x8111e180): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:26.409 ( 509.800s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x81984b60): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:26.513 ( 509.904s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x8115f660): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:27.460 ( 510.851s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x80017e90): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:27.597 ( 510.987s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x8001f640): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:27.710 ( 511.101s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x80017e90): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:27.944 ( 511.335s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5dfa50e0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:28.042 ( 511.433s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7b446240): EGL device index: 0 could not be initialized. Trying other devices...
# Generating frames:  95%|█████████▍| 37/39 [05:09<00:16,  8.48s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:34.058 ( 517.449s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7f2b0cc0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:34.169 ( 517.559s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x8001f640): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:34.261 ( 517.652s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7f2b0cc0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:34.586 ( 517.977s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x8001f640): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:34.695 ( 518.086s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x81984b60): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:35.653 ( 519.044s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7ca53340): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:35.761 ( 519.151s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x8001f640): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:35.876 ( 519.267s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7ca53340): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:36.136 ( 519.526s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x79a8ad70): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:36.253 ( 519.643s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5ab1c220): EGL device index: 0 could not be initialized. Trying other devices...
# Generating frames:  97%|█████████▋| 38/39 [05:17<00:08,  8.39s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:42.257 ( 525.647s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x83e60130): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:42.377 ( 525.768s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x8001f640): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:42.502 ( 525.892s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x83e60130): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:42.797 ( 526.187s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x8001f640): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:42.918 ( 526.308s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7683b1d0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:44.091 ( 527.482s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7f08e8d0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:44.189 ( 527.580s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x749d6640): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:44.324 ( 527.714s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7f08e8d0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:44.653 ( 528.044s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x749d6640): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-15 18:29:44.799 ( 528.190s) [    7F5842EE7440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x80a3a730): EGL device index: 0 could not be initialized. Trying other devices...
# Generating frames: 100%|██████████| 39/39 [05:27<00:00,  8.39s/it]
# Video saved to ../img/insula_hga_production.gif

# %% [markdown]
# # Perception

# %%
# 3D Insula HGA Video Generation - Perception
# 重新加载perception数据
task = ['PhonemeSequence', 'SentenceRep', 'TIMIT', 'LexicalDelay']
ref = 'bipolar'

time_paths = []
for t in task:
    time_paths.extend(
        BIDSPath(
            root=f'../results/{t}({ref})',
            datatype='HGA',
            suffix='time',
            check=False,
        ).match()
    )

time_dfs = []
for path in tqdm(time_paths):
    df = pd.read_csv(path)
    time_dfs.append(df)

listen_data = pd.concat(time_dfs)

# rename ROIs
listen_data.loc[listen_data.roi == 'INS', 'roi'] = 'Insula'
listen_data.loc[listen_data.roi == 'HG', 'roi'] = 'STG'
listen_data.loc[listen_data.roi == 'PrG', 'roi'] = 'SMC'
listen_data.loc[listen_data.roi == 'PoG', 'roi'] = 'SMC'
listen_data.loc[listen_data.roi == 'Subcentral', 'roi'] = 'SMC'

# 筛选perception/passive数据
listen_data = listen_data[~listen_data.description.isin(['production'])]
listen_data = listen_data[~listen_data.phase.isin(['Go', 'Response'])]

# 筛选时间范围和insula
listen_data = listen_data[(listen_data['time'] >= -1) & (listen_data['time'] <= 1)]
insula_listen = listen_data[listen_data['roi'] == 'Insula'].copy()
print(f"Insula electrodes (perception): {insula_listen['channel'].nunique()}")
# Out:
#  98%|█████████▊| 954/975 [00:52<00:01, 13.49it/s]

# %%
# 参数设置
window_size = 0.1  # 100ms window
step_size = 0.05   # 50ms step
time_min_p, time_max_p = insula_listen['time'].min(), insula_listen['time'].max()
time_points_p = np.arange(time_min_p, time_max_p - window_size + step_size, step_size)

# 固定的vmin, vmax (across all windows)
all_values_p = insula_listen['value'].values
vmin_p, vmax_p = 0, np.percentile(all_values_p[all_values_p > 0], 95)
print(f"Fixed colormap range: [{vmin_p:.3f}, {vmax_p:.3f}]")

# 使用blues colormap
cmap_p = blues

def generate_frame_perception(t_start, insula_data, lh_tree, rh_tree, lh_pial_coords, rh_pial_coords,
                               labels, insula_patterns, lh_insula_center, rh_insula_center,
                               cmap, vmin, vmax, size_min, size_max, window_size, time_min, time_max):
    """生成单帧图像 - Perception"""
    t_end = t_start + window_size
    
    # 计算当前窗口的HGA
    window_data = insula_data[(insula_data['time'] >= t_start) & (insula_data['time'] < t_end)]
    hga_df = window_data.groupby('channel').agg({
        'value': 'mean',
        'x': 'first', 'y': 'first', 'z': 'first'
    }).reset_index()
    
    if len(hga_df) == 0:
        return None
    
    cord = hga_df[['x', 'y', 'z']].values
    hga_values = hga_df['value'].values
    mask_lh = cord[:, 0] < 0
    mask_rh = cord[:, 0] > 0
    
    norm = mcolors.Normalize(vmin=vmin, vmax=vmax)
    
    # 创建Brain对象
    lh_brain = Brain("fsaverage", subjects_dir=recon_dir, surf="pial",
                     hemi="lh", background="white", show=False,
                     cortex=(0.9, 0.9, 0.9), alpha=0.05, size=(800, 800))
    rh_brain = Brain("fsaverage", subjects_dir=recon_dir, surf="pial",
                     hemi="rh", background="white", show=False,
                     cortex=(0.9, 0.9, 0.9), alpha=0.05, size=(800, 800))
    
    # 添加insula labels
    for lab in labels:
        if any(pattern in lab.name for pattern in insula_patterns):
            if lab.hemi == 'lh':
                lh_brain.add_label(lab, borders=False, color=(0.9, 0.9, 0.9), alpha=0.6)
            elif lab.hemi == 'rh':
                rh_brain.add_label(lab, borders=False, color=(0.9, 0.9, 0.9), alpha=0.6)
    
    # 添加电极
    def add_electrodes(brain, coords, hga_vals, tree, pial_coords):
        if len(coords) == 0:
            return
        _, indices = tree.query(coords)
        coords_proj = pial_coords[indices]
        for i in range(len(coords_proj)):
            pt = coords_proj[i:i+1]
            hga = hga_vals[i]
            color = cmap(norm(hga))[:3]
            size = hga_to_size(hga, vmin, vmax, size_min, size_max)
            cloud = pv.PolyData(pt)
            brain._renderer.plotter.add_mesh(cloud, render_points_as_spheres=True,
                                             point_size=size, color=color, lighting=False)
    
    if mask_lh.any():
        add_electrodes(lh_brain, cord[mask_lh], hga_values[mask_lh], lh_tree, lh_pial_coords)
    if mask_rh.any():
        add_electrodes(rh_brain, cord[mask_rh], hga_values[mask_rh], rh_tree, rh_pial_coords)
    
    # 设置视角
    lh_brain.show_view(azimuth=180, elevation=90, distance=180, focalpoint=lh_insula_center)
    rh_brain.show_view(azimuth=0, elevation=90, distance=180, focalpoint=rh_insula_center)
    
    # 创建图像
    fig, axes = plt.subplots(1, 2, figsize=(16*cm, 10*cm))
    
    axes[0].imshow(lh_brain.screenshot(mode="rgb"))
    axes[0].axis("off")
    axes[0].set_title("Left Insula", fontsize=fontsize)
    
    axes[1].imshow(rh_brain.screenshot(mode="rgb"))
    axes[1].axis("off")
    axes[1].set_title("Right Insula", fontsize=fontsize)
    
    lh_brain.close()
    rh_brain.close()
    
    # 添加colorbar
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])
    cbar = fig.colorbar(sm, ax=axes, orientation='horizontal', fraction=0.04, pad=0.02, aspect=30)
    cbar.set_label('HGA (z-score)', fontsize=fontsize)
    cbar.ax.tick_params(labelsize=fontsize)
    
    # 添加时间轴
    ax_time = fig.add_axes([0.15, 0.02, 0.7, 0.03])
    ax_time.set_xlim(time_min, time_max)
    ax_time.set_ylim(0, 1)
    ax_time.axvline(x=0, color='gray', linestyle='--', linewidth=0.5)
    
    # 当前时间窗口
    ax_time.axvspan(t_start, t_end, color=blue, alpha=0.5)
    ax_time.plot((t_start + t_end) / 2, 0.5, 'ko', markersize=5)
    
    ax_time.set_xlabel('Time (s)', fontsize=fontsize)
    ax_time.set_yticks([])
    ax_time.tick_params(labelsize=fontsize)
    for spine in ['top', 'left', 'right']:
        ax_time.spines[spine].set_visible(False)
    
    plt.suptitle(f"Perception HGA: {t_start:.2f}s - {t_end:.2f}s", fontsize=fontsize+1)
    
    # 转换为图像数组
    buf = BytesIO()
    fig.savefig(buf, format='png', dpi=100, bbox_inches='tight')
    buf.seek(0)
    img = np.array(Image.open(buf).convert('RGB'))
    buf.close()
    plt.close(fig)
    
    return img

# 生成所有帧
frames_p = []
for t in tqdm(time_points_p, desc="Generating perception frames"):
    img = generate_frame_perception(t, insula_listen, lh_tree, rh_tree, lh_pial_coords, rh_pial_coords,
                                     labels, insula_patterns, lh_insula_center, rh_insula_center,
                                     cmap_p, vmin_p, vmax_p, size_min, size_max, window_size, time_min_p, time_max_p)
    if img is not None:
        frames_p.append(img)

# 保存视频
output_path_p = '../img/insula_hga_perception.gif'
imageio.mimsave(output_path_p, frames_p, duration=100)
print(f"Video saved to {output_path_p}")
# Out:
# Fixed colormap range: [0.000, 1.161]
# Generating perception frames:   0%|          | 0/39 [00:00<?, ?it/s]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:07.707 (7222.243s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x3ea0ebb0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:07.779 (7222.314s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x3ea0ebb0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:07.841 (7222.377s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5d4317e0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:07.978 (7222.514s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5757afc0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:08.025 (7222.561s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x56ddab00): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:08.641 (7223.177s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x503b41e0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:08.696 (7223.232s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5757afc0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:08.751 (7223.287s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x520c0d20): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:08.876 (7223.412s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5757afc0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:08.936 (7223.471s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x503b41e0): EGL device index: 0 could not be initialized. Trying other devices...
# Generating perception frames:   3%|▎         | 1/39 [00:03<02:27,  3.87s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:11.517 (7226.053s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4b312d30): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:11.579 (7226.115s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4b312d30): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:11.640 (7226.176s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x59d64d00): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:11.787 (7226.323s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x1b2b58b0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:11.840 (7226.376s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5757afc0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:12.565 (7227.101s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6608c340): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:12.621 (7227.157s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x1b2b58b0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:12.670 (7227.206s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6738a3d0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:12.796 (7227.332s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4513f8d0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:12.851 (7227.387s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6608c340): EGL device index: 0 could not be initialized. Trying other devices...
# Generating perception frames:   5%|▌         | 2/39 [00:07<02:24,  3.89s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:15.415 (7229.951s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4513c330): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:15.473 (7230.009s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4513c330): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:15.534 (7230.070s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4b2a82c0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:15.688 (7230.223s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4ff88270): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:15.740 (7230.276s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4513f8d0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:16.293 (7230.829s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x45052290): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:16.347 (7230.883s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4ff88270): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:16.402 (7230.938s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x45052290): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:16.578 (7231.114s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4628f5f0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:16.631 (7231.167s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4ff88270): EGL device index: 0 could not be initialized. Trying other devices...
# Generating perception frames:   8%|▊         | 3/39 [00:11<02:16,  3.80s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:19.105 (7233.641s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x590b9d30): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:19.165 (7233.700s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x590b9d30): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:19.225 (7233.761s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x706a1190): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:19.358 (7233.894s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x590b9d30): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:19.411 (7233.947s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0xf33efd0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:19.928 (7234.464s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x539cb620): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:19.991 (7234.526s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x53e3b450): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:20.038 (7234.574s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x539cb620): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:20.158 (7234.694s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x65d6ed80): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:20.327 (7234.862s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x53e3b450): EGL device index: 0 could not be initialized. Trying other devices...
# Generating perception frames:  10%|█         | 4/39 [00:15<02:12,  3.79s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:22.887 (7237.423s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x46ae61d0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:22.961 (7237.496s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x46ae61d0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:23.040 (7237.576s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x45aca100): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:23.214 (7237.750s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x3e05df30): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:23.253 (7237.789s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x65d6ed80): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:23.792 (7238.328s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x2db659f0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:23.842 (7238.378s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x2db659f0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:23.887 (7238.423s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x3e05df30): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:24.010 (7238.546s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x2db659f0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:24.055 (7238.591s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x497f4b00): EGL device index: 0 could not be initialized. Trying other devices...
# Generating perception frames:  13%|█▎        | 5/39 [00:19<02:10,  3.83s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:26.793 (7241.329s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x2db659f0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:26.853 (7241.389s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x2db659f0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:26.914 (7241.450s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x575b44c0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:27.032 (7241.568s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x48706c60): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:27.072 (7241.608s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x567604d0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:27.563 (7242.098s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7414e60): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:27.603 (7242.139s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7414e60): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:27.643 (7242.179s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x48706c60): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:27.751 (7242.287s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x457a1fc0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:27.791 (7242.327s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7414e60): EGL device index: 0 could not be initialized. Trying other devices...
# Generating perception frames:  15%|█▌        | 6/39 [00:22<02:01,  3.69s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:30.228 (7244.764s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x457a1fc0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:30.308 (7244.844s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x457a1fc0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:30.388 (7244.924s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x575b44c0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:30.538 (7245.074s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x65350630): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:30.592 (7245.128s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x45834530): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:31.163 (7245.699s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x635b4520): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:31.217 (7245.753s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5786d9e0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:31.269 (7245.804s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x635b4520): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:31.383 (7245.918s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0xac78190): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:31.442 (7245.978s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4628f5f0): EGL device index: 0 could not be initialized. Trying other devices...
# Generating perception frames:  18%|█▊        | 7/39 [00:26<02:00,  3.77s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:34.144 (7248.680s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x14241000): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:34.211 (7248.746s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x14241000): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:34.273 (7248.809s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5d4317e0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:34.403 (7248.939s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0xaccbbe0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:34.447 (7248.983s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5786d9e0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:34.947 (7249.483s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4c1199d0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:35.002 (7249.538s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4c1199d0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:35.056 (7249.591s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0xaccbbe0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:35.189 (7249.724s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x31c25430): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:35.230 (7249.766s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4c1199d0): EGL device index: 0 could not be initialized. Trying other devices...
# Generating perception frames:  21%|██        | 8/39 [00:30<01:54,  3.70s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:37.692 (7252.227s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x43e02f90): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:37.760 (7252.295s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x43e02f90): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:37.820 (7252.356s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x60ebf910): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:37.944 (7252.480s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x43e02f90): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:37.984 (7252.520s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x31c25430): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:38.525 (7253.061s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7112b5a0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:38.569 (7253.105s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x43e02f90): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:38.611 (7253.147s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x7112b5a0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:38.715 (7253.250s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x46cb9960): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:38.753 (7253.289s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x43e02f90): EGL device index: 0 could not be initialized. Trying other devices...
# Generating perception frames:  23%|██▎       | 9/39 [00:33<01:50,  3.67s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:41.286 (7255.822s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5efec9b0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:41.352 (7255.888s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5efec9b0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:41.430 (7255.965s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x52805fb0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:41.584 (7256.120s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5efec9b0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:41.642 (7256.178s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x50a02fe0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:42.190 (7256.725s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x64176520): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:42.235 (7256.771s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5efec9b0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:42.282 (7256.818s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x64176520): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:42.392 (7256.928s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x45e0bbe0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:42.438 (7256.974s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5efec9b0): EGL device index: 0 could not be initialized. Trying other devices...
# Generating perception frames:  26%|██▌       | 10/39 [00:37<01:46,  3.68s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:45.000 (7259.536s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x50225790): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:45.074 (7259.610s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x50225790): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:45.154 (7259.690s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x522799c0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:45.313 (7259.849s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x50225790): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:45.356 (7259.892s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x45e0bbe0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:45.921 (7260.457s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x74419550): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:45.972 (7260.508s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x50225790): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:46.022 (7260.558s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6a507f90): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:03:46.163 (7260.699s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x634e09d0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# ...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:20.400 (7354.936s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x2d5fc610): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:20.952 (7355.488s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x56c54530): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:20.998 (7355.534s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x44bc8f40): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:21.048 (7355.584s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x56c54530): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:21.172 (7355.708s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x44bc8f40): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:21.223 (7355.759s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x528a4360): EGL device index: 0 could not be initialized. Trying other devices...
# Generating perception frames:  92%|█████████▏| 36/39 [02:16<00:11,  3.75s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:23.803 (7358.339s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4a0e32c0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:23.875 (7358.411s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4a0e32c0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:23.951 (7358.487s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5f028790): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:24.095 (7358.630s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4a0e32c0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:24.140 (7358.676s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x360233e0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:24.949 (7359.485s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6ec28980): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:24.998 (7359.534s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4a0e32c0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:25.039 (7359.574s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6ec28980): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:25.142 (7359.678s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6125df60): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:25.185 (7359.721s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4a0e32c0): EGL device index: 0 could not be initialized. Trying other devices...
# Generating perception frames:  95%|█████████▍| 37/39 [02:20<00:07,  3.83s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:27.814 (7362.350s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5703c390): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:27.890 (7362.425s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5703c390): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:27.950 (7362.486s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x11c2b940): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:28.075 (7362.611s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5703c390): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:28.117 (7362.653s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x6125df60): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:28.658 (7363.193s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x370bdc00): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:28.716 (7363.251s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5703c390): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:28.773 (7363.309s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x370bdc00): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:28.884 (7363.420s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5703c390): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:28.934 (7363.470s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x64d624f0): EGL device index: 0 could not be initialized. Trying other devices...
# Generating perception frames:  97%|█████████▋| 38/39 [02:23<00:03,  3.79s/it]VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:31.503 (7366.039s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x30c8e200): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:31.575 (7366.111s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x30c8e200): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:31.642 (7366.178s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5f028790): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:31.772 (7366.308s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x30c8e200): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:31.815 (7366.351s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5703c390): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:32.303 (7366.839s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5f932360): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:32.346 (7366.882s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4628de90): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:32.392 (7366.928s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x5f932360): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:32.505 (7367.041s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x573ff8f0): EGL device index: 0 could not be initialized. Trying other devices...
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# VMware: No 3D enabled (0, Success).
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# 2025-12-14 18:05:32.549 (7367.085s) [    7F38A9534440] vtkEGLRenderWindow.cxx:353   WARN| vtkEGLRenderWindow (0x4628de90): EGL device index: 0 could not be initialized. Trying other devices...
# Generating perception frames: 100%|██████████| 39/39 [02:27<00:00,  3.78s/it]
# Video saved to ../img/insula_hga_perception.gif
